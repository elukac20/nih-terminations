# %%
import pandas as pd
import itertools

# %% [markdown]
# Data from NIH data
#
# https://grant-witness.us/nih-data.html
#
# https://hsph.harvard.edu/news/creating-a-trusted-database-of-federal-research-funding-cuts/

# %%
df = pd.read_csv('./data/nih_v3_terminations.csv')

# %%
df
# Out:
#       grant_id subgrant_id core_award_number  full_award_number activity_code  \
# 0     AA007459         NaN       T32AA007459    5T32AA007459-40           T32
# 1     AA019072         NaN       P01AA019072    5P01AA019072-15           P01
# 2     AA024434         NaN       R01AA024434    5R01AA024434-10           R01
# 3     AA026186         NaN       R01AA026186    5R01AA026186-10           R01
# 4     AA026297         NaN       R01AA026297    5R01AA026297-09           R01
# ...        ...         ...               ...                ...           ...
# 5516  TW012677         NaN       R01TW012677  1R01TW012677-01A1           R01
# 5517  TW012808         NaN       P20TW012808    5P20TW012808-02           P20
# 5518  TW012850         NaN       K43TW012850    5K43TW012850-02           K43
# 5519  TW012904         NaN       R01TW012904    5R01TW012904-02           R01
# 5520  TW013028         NaN       P20TW013028    5P20TW013028-02           P20
#
#      institute_code  subproject_id current_status           detailed_status  \
# 0                AA            NaN       Restored      Unfrozen (confirmed)
# 1                AA            NaN       Restored      Unfrozen (confirmed)
# 2                AA            NaN       Restored      Unfrozen (confirmed)
# 3                AA            NaN       Restored      Unfrozen (confirmed)
# 4                AA            NaN       Restored      Unfrozen (confirmed)
# ...             ...            ...            ...                       ...
# 5516             TW            NaN       Restored      Unfrozen (confirmed)
# 5517             TW            NaN       Restored    Reinstated (confirmed)
# 5518             TW            NaN       Restored  Reinstated (unconfirmed)
# 5519             TW            NaN       Restored    Reinstated (confirmed)
# 5520             TW            NaN       Restored    Reinstated (confirmed)
#
#                                                   title  ...  \
# 0     Alcohol Intervention Treatment Outcome Researc...  ...
# 1     Addressing alcohol misuse in HIV prevention an...  ...
# 2     Notch-dependent microcircuit regulation of alc...  ...
# 3     Endocannabinoid Mechanisms in the Pathophysiol...  ...
# 4     Aldh2 and epithelial homeostasis and pathobiology  ...
# ...                                                 ...  ...
# 5516  Engaging Vulnerable Women in HIV Prevention an...  ...
# 5517  The Anga Center for Community Health and Well-...  ...
# 5518  Adapting an evidence-based intervention to imp...  ...
# 5519  Kabawil: Adapting an Intervention to Reduce In...  ...
# 5520  Center for Effective and Accessible Research-b...  ...
#
#                                       opportunity_title  \
# 0     Ruth L. Kirschstein National Research Service ...
# 1     Alcohol-HIV/AIDS Program Project (P01 Clinical...
# 2     Research Project Grant (Parent R01 Clinical Tr...
# 3     NIH Research Project Grant (Parent R01 Clinica...
# 4     NIH Research Project Grant (Parent R01 Clinica...
# ...                                                 ...
# 5516  Interventions for Stigma Reduction to Improve ...
# 5517  Exploratory Grants for Climate Change and Heal...
# 5518  Emerging Global Leader Award (K43 Independent ...
# 5519  Interventions for Stigma Reduction to Improve ...
# 5520  Exploratory Grants for Climate Change and Heal...
#
#                                         opportunity_url  \
# 0     https://grants.nih.gov/grants/guide/pa-files/P...
# 1     https://grants.nih.gov/grants/guide/pa-files/R...
# 2     https://grants.nih.gov/grants/guide/pa-files/P...
# 3     https://grants.nih.gov/grants/guide/pa-files/P...
# 4     https://grants.nih.gov/grants/guide/pa-files/P...
# ...                                                 ...
# 5516  https://grants.nih.gov/grants/guide/pa-files/P...
# 5517  https://grants.nih.gov/grants/guide/pa-files/R...
# 5518  https://grants.nih.gov/grants/guide/pa-files/P...
# 5519  https://grants.nih.gov/grants/guide/pa-files/P...
# 5520  https://grants.nih.gov/grants/guide/pa-files/R...
#
#      current_total_obligated post_termination_deobligation  award_value  \
# 0                 8903933.00                           NaN   8903933.00
# 1                19658333.00                           NaN  19658333.00
# 2                 3903456.00                           NaN   3903456.00
# 3                 3188075.26                           NaN   3188075.26
# 4                 2928362.18                           NaN   2928362.18
# ...                      ...                           ...          ...
# 5516               173197.00                           NaN    173197.00
# 5517              2109010.00                           NaN   2109010.00
# 5518               134406.00                           NaN    134406.00
# 5519               432176.00                           NaN    432176.00
# 5520              2525164.00                           NaN   2525164.00
#
#      award_outlaid award_remaining  \
# 0       2021558.65      6882374.35
# 1       4853500.60     14804832.40
# 2       1545133.43      2358322.57
# 3       1317401.98      1870673.28
# 4       1226006.45      1702355.73
# ...            ...             ...
# 5516     169209.31         3987.69
# 5517      60720.12      2048289.88
# 5518      66427.00        67979.00
# 5519     220077.98       212098.02
# 5520     845984.22      1679179.78
#
#                                            reporter_url  \
# 0     https://reporter.nih.gov/project-details/11098673
# 1     https://reporter.nih.gov/project-details/10879090
# 2     https://reporter.nih.gov/project-details/11137591
# 3     https://reporter.nih.gov/project-details/11324549
# 4     https://reporter.nih.gov/project-details/11381708
# ...                                                 ...
# 5516  https://reporter.nih.gov/project-details/11002762
# 5517  https://reporter.nih.gov/project-details/11397208
# 5518  https://reporter.nih.gov/project-details/11374076
# 5519  https://reporter.nih.gov/project-details/11362792
# 5520  https://reporter.nih.gov/project-details/11193870
#
#                                         usaspending_url taggs_url
# 0     https://www.usaspending.gov/award/ASST_NON_T32...       NaN
# 1     https://www.usaspending.gov/award/ASST_NON_P01...       NaN
# 2     https://www.usaspending.gov/award/ASST_NON_R01...       NaN
# 3     https://www.usaspending.gov/award/ASST_NON_R01...       NaN
# 4     https://www.usaspending.gov/award/ASST_NON_R01...       NaN
# ...                                                 ...       ...
# 5516  https://www.usaspending.gov/award/ASST_NON_R01...       NaN
# 5517  https://www.usaspending.gov/award/ASST_NON_P20...       NaN
# 5518  https://www.usaspending.gov/award/ASST_NON_K43...       NaN
# 5519  https://www.usaspending.gov/award/ASST_NON_R01...       NaN
# 5520  https://www.usaspending.gov/award/ASST_NON_P20...       NaN
#
# [5521 rows x 63 columns]

# %%
df.columns
# Out:
# Index(['grant_id', 'subgrant_id', 'core_award_number', 'full_award_number',
#        'activity_code', 'institute_code', 'subproject_id', 'current_status',
#        'detailed_status', 'title', 'latest_disruption_date',
#        'latest_restoration_date', 'first_termination_date',
#        'latest_termination_date', 'first_reinstatement_date',
#        'latest_reinstatement_date', 'frozen_date', 'unfrozen_date',
#        'latest_outlay', 'latest_renewal', 'latest_budget_end', 'project_start',
#        'project_end', 'event_history', 'signals', 'has_been_terminated',
#        'has_been_reinstated', 'has_been_frozen', 'has_been_unfrozen',
#        'has_been_delayed', 'study_section', 'abstract',
#        'public_health_relevance', 'terms', 'spending_categories',
#        'categories_predicted', 'funding_category', 'program_office',
#        'nih_activity', 'flagged_words', 'org_name', 'org_state', 'org_city',
#        'org_country', 'org_type', 'org_traits', 'pct_ugrad_pellgrant',
#        'pct_ugrad_fedloan', 'department_type', 'congressional_district',
#        'cfda_number', 'cfda_title', 'opportunity_number', 'opportunity_title',
#        'opportunity_url', 'current_total_obligated',
#        'post_termination_deobligation', 'award_value', 'award_outlaid',
#        'award_remaining', 'reporter_url', 'usaspending_url', 'taggs_url'],
#       dtype='object')

# %%
flagged_new_all = pd.Series(df['flagged_words'].tolist()).dropna().tolist()
flagged_new = set(list(itertools.chain.from_iterable([i.split(', ') for i in flagged_new_all])))


len(flagged_new)
# Out:
# 167

# %% [markdown]
# From https://pen.org/banned-words-list/

# %%
# banned_words = """abortion accessibility Accessible activism activists advocacy advocate advocates affirmative action affirmative action programs affirming care affordable home affordable housing agricultural water agrivoltaics air pollution all-inclusive allyship alternative energy anti-racism antiracist asexual assigned at birth assigned female at birth assigned male at birth at risk autism aviation fuel barrier barriers belong bias biased Biased toward biases Biases towards bioenergy biofuel biogas biologically female biologically male biomethane bipoc bisexual Black black and latinx breastfeed + people breastfeed + person Cancer Moonshot carbon emissions mitigation carbon footprint carbon markets carbon pricing carbon sequestration CEC changing climate chestfeed + people chestfeed + person clean energy clean fuel clean power clean water climate climate accountability climate change climate consulting climate crisis climate model climate models climate resilience climate risk climate science climate smart agriculture climate smart forestry climate variability climate-change climatesmart commercial sex worker community community diversity community equity confirmation bias contaminants of environmental concern continuum Covid-19 critical race theory cultural competence cultural differences cultural heritage Cultural relevance cultural sensitivity culturally appropriate culturally responsive decarbonization definition DEI DEIA DEIAB DEIJ diesel dietary guidelines/ultraprocessed foods dirty energy disabilities disability disabled disadvantaged discriminated discrimination discriminatory discussion of federal policies disparity diverse diverse backgrounds diverse communities diverse community diverse group diverse groups diversified diversify diversifying diversity diversity and inclusion diversity in the workplace diversity, equity, and inclusion diversity/equity efforts EEJ EJ elderly electric vehicle emissions energy conversion energy transition enhance the diversity enhancing diversity entitlement environmental justice environmental quality equal opportunity equality equitable equitableness equity ethnicity evidence-based excluded exclusion expression female females feminism fetus field drainage fluoride fostering inclusivity fuel cell gay GBV gender gender based gender based violence gender diversity gender dysphoria gender expression gender identity gender ideology gender nonconformity gender transition gender-affirming care gendered genders geothermal GHG emission GHG modeling GHG monitoring global warming green green infrastructure greenhouse gas emission groundwater pollution Gulf of Mexico H5N1/bird flu hate hate speech health disparity health equity hispanic hispanic minority historically housing affordability housing efficiency hydrogen vehicle identity ideology immigrants implicit bias implicit biases inclusion inclusive inclusive leadership inclusiveness inclusivity Increase diversity increase the diversity indigenous indigenous community/ people inequalities inequality inequitable inequities injustice institutional integration intersectional intersectionality intersex issues concerning pending legislation justice40 key groups key people key populations Latinx lesbian lgbt LGBTQ low-emission vehicle low-income housing male dominated marginalize marginalized marijuana measles membrane filtration men who have sex with men mental health methane emissions microplastics migrant minorities minority minority serving institution most risk MSI msm multicultural Mx Native American NCI budget net-zero non-binary nonbinary noncitizen non-conforming nonpoint source pollution nuclear energy nuclear power obesity opioids oppression oppressive orientation pansexual PCB peanut allergies people + uterus people of color people-centered care person-centered person-centered care PFAS PFOA photovoltaic polarization political pollution pollution abatement pollution remediation prefabricated housing pregnant people pregnant person pregnant persons prejudice privilege privileges promote promote diversity promoting diversity pronoun pronouns prostitute pyrolysis QT queer race race and ethnicity racial racial diversity racial identity racial inequality racial justice racially racism runoff rural water safe drinking water science-based sediment remediation segregation self-assessed sense of belonging sex sexual preferences sexuality social justice social vulnerability socio cultural socio economic sociocultural socioeconomic status soil pollution solar energy solar power special populations stem cell or fetal tissue research stereotype stereotypes subsidized housing sustainability/sustainable sustainable construction systemic systemically tax breaks tax credits tax subsidies they/them tile drainage topics of federal investigations topics that have received recent attention from Congress topics that have received widespread or critical media attention trans transexual transexualism transexuals transgender transgender military personnel transgender people transitional housing trauma traumatic tribal two-spirit unconscious bias under appreciated under represented under served underprivileged underrepresentation underrepresented underserved understudied undervalued vaccines victim victims vulnerable vulnerable populations water collection water conservation water distribution water efficiency water management water pollution water quality water storage water treatment white privilege wind power woman women women and underrepresented women in leadership""".split()

# %% [markdown]
# From Sen. Cruz's list (official)

# %%
statusbanstring = '''
ACTIVISM; ACTIVIST; ACTIVISTS; ADVOCACY; ADVOCATE; ADVOCATES; AFFIRMATIVE ACTION; BIAS TOWARD;
 BIAS TOWARDS; BIASED; BIASED TOWARD; BIASED TOWARDS; BIASES; BIASES TOWARD; BIASES TOWARDS; DE
COLONIZATION; DE COLONIZE; DE COLONIZED; DE COLONIZING; DE SEGREGATE; DE SEGREGATED; DE
SEGREGATES; DE SEGREGATION; DECOLONIZATION; DECOLONIZE; DECOLONIZED; DECOLONIZING;
DESEGREGATE; DESEGREGATED; DESEGREGATES; DESEGREGATION; DISCRIMINATE; DISCRIMINATED;
DISCRIMINATION; DISCRIMINATORY; DIVISIVENESS; EXCLUDED; EXCLUSION; EXCLUSIVE; FEEL SEEN AND HEARD;
HATE SPEECH; HISTORICALLY; IMPLICIT BIAS; IMPLICIT BIASES; INJUSTICE; INJUSTICES; INSTITUTIONAL;
INSTITUTIONALIZE; INSTITUTIONALIZED; INSTITUTIONALLY; INTERGENERATIONAL TRAUMA; INTERSECTIONAL;
INTERSECTIONALITY; MARGINALIZATION; MARGINALIZE; MARGINALIZED; MICRO AGGRESSION; MICRO
AGGRESSIONS; MICRO AGGRESSIVE; MICRO AGGRESSIVENESS; MICROAGGRESSION; MICROAGGRESSIONS;
MICROAGGRESSIVE; MICROAGGRESSIVENESS; MINORITIES; MINORITY; OPPRESSED; OPPRESSIVE;
OPPRESSIVENESS; OPPRESSION; POLARIZATION; POLARIZE; POLITICIZATION; POLITICIZE; POLITICAL; PREJUDICE;
PREJUDICES; PRIVILEGE; PRIVILEGED; PRIVILEGES; REPARATION; REPARATIONS; SEGREGATED; SEGREGATION;
SOCIO ECONOMIC; SOCIOECONOMIC; STATUS; STATUSES; STEREOTYPE; STEREOTYPES; STEREOTYPICAL;
STEREOTYPING; SYSTEM OF OPPRESSION; SYSTEMATIC OPPRESSION; SYSTEMATICALLY OPPRESSED; SYSTEMIC;
SYSTEMIC OPPRESSION; SYSTEMICAL; SYSTEMICALLY; SYSTEMICALLY OPPRESSED; SYSTEMS OF OPPRESSION;
SYSTEMS OF POWER; TRAUMA; TRAUMATIC; UNDER APPRECIATED; UNDER APPRECIATION; UNDER PRIVILEGE;
UNDER PRIVILEGED; UNDER REPRESENTATION; UNDER REPRESENTED; UNDER SERVED; UNDER SERVING; UNDER
VALUED; UNDER VALUING; UNDERAPPRECIATED; UNDERAPPRECIATION; UNDERPRIVILEGE; UNDERPRIVILEGED;
UNDERREPRESENTATION; UNDERREPRESENTED; UNDERSERVED; UNDERSERVING; UNDERVALUED; UNDERVALUING;
UNJUST; VICTIM; VICTIMHOOD; VICTIMIZED; VICTIMS; VOICES ARE ACKNOWLEDGED; VOICES HEARD; VOICES
MATTER; UNEQUAL OPPORTUNITIES; UNEQUAL OPPORTUNITY; SAFE SPACE; SAFE SPACES; SENSE OF
BELONGING; SENSE OF BELONGINGNESS; WELCOMING ENVIRONMENT; BARRIER; BARRIERS; DISABILITIES;
DISABILITY; ALLY; ALLYSHIP.
'''

socialbanstring = '''
ADVANCE DIVERSITY; ADVANCE INCLUSIVITY; ADVANCE THE DIVERSITY; ADVANCING DIVERSITY; ADVANCING 
INCLUSIVE; ALLIANCE FOR DIVERSITY; BACKGROUND INCLUSIVITY; BI CULTURAL; BICULTURAL; BLACK CULTURAL;
BLACK CULTURE; BLACK CULTURES; BROADEN DIVERSITY; BROADEN THE DIVERSITY; COMMITMENT TO DIVERSITY;
COMMUNITY DIVERSITY; COMMUNITY EQUITY; COMMUNITY INCLUSIVITY; CULTURAL ACTIVISM; CULTURAL
ACTIVIST; CULTURAL ACTIVISTS; CULTURAL ADVOCACY; CULTURAL ADVOCATE; CULTURAL AND ETHNIC;
CULTURAL AND RACIAL; CULTURAL APPROPRIATION; CULTURAL APPROPRIATIONS; CULTURAL BIAS; CULTURAL
COMPETENCY; CULTURAL CONNECTIONS; CULTURAL DIFFERENCES; CULTURAL HERITAGE; CULTURAL HUMILITY;
CULTURAL INEQUALITIES; CULTURAL INEQUALITY; CULTURAL INEQUITIES; CULTURAL INEQUITY; CULTURAL
INJUSTICE; CULTURAL INJUSTICES; CULTURAL JUSTICE; CULTURAL RELEVANCE; CULTURAL SEGREGATION;
CULTURALLY ATTUNED; CULTURALLY BIASED; CULTURALLY RESPONSIVE; CULTURALLY SENSITIVE; CULTURALLY
SUSTAINABLE; CULTURALLY SUSTAINING; CULTURE AND ETHNICITY; CULTURE AND RACE; CULTURES AND
ETHNICITIES; CULTURES AND RACES; DEI; DEIJ; DIVERSE BACKGROUND; DIVERSE BACKGROUNDS; DIVERSE
COMMUNITIES; DIVERSE COMMUNITY; DIVERSE GROUP; DIVERSE GROUPS; DIVERSE INDIVIDUAL; DIVERSE
INDIVIDUALS; DIVERSE STATUS; DIVERSE STATUSES; DIVERSE VOICES; DIVERSIFIED; DIVERSIFY; DIVERSIFYING;
DIVERSITY AND EQUITY; DIVERSITY AND INCLUSION; DIVERSITY AND INCLUSIVITY; DIVERSITY AWARENESS;
DIVERSITY EQUITY; EMPHASIS ON DIVERSITY; EMPHASIZE DIVERSITY; EMPHASIZING DIVERSITY; ENCOURAGE
DIVERSITY; ENCOURAGING DIVERSITY; ENHANCE DIVERSITY; ENHANCE THE DIVERSITY; ENHANCING DIVERSITY;
EQUAL OPPORTUNITIES; EQUAL OPPORTUNITY; EQUALITIES; EQUALITY; EQUITABLE; EQUITABLE AND INCLUSIVE;
EQUITIES; EQUITY; ETHNIC AND CULTURAL; ETHNIC CULTURAL; ETHNIC CULTURE; ETHNIC CULTURES; ETHNIC
DIVERSITY; ETHNIC EQUITY; ETHNICITIES AND CULTURES; ETHNICITY AND CULTURE; FOSTER DIVERSITY;
FOSTERING DIVERSITY; FOSTERING INCLUSIVE; FOSTERING INCLUSIVITY; FOSTERING THE DIVERSITY; GROUP
EQUITY; GROUP INCLUSIVITY; HISPANIC CULTURAL; HISPANIC CULTURE; HISPANIC CULTURES; INCLUSION;
INCLUSIVE; INCLUSIVE LANGUAGE; INCLUSIVENESS; INCLUSIVITY; INCLUSIVITY AND DIVERSITY; INCREASE DIVERSITY;
INCREASE THE DIVERSITY; INCREASES DIVERSITY; INCREASES THE DIVERSITY; INCREASING DIVERSITY; INCREASING
THE DIVERSITY; INDIGENOUS CULTURAL; INDIGENOUS CULTURE; INDIGENOUS CULTURES; INEQUALITIES;
INEQUALITY; INEQUITABLE; INEQUITIES; INEQUITY; INTER CULTURAL; INTER CULTURALLY; INTERCULTURAL;
INTERCULTURALLY; LACK OF DIVERSITY; LATINX CULTURAL; LATINX CULTURE; LATINX CULTURES; MULTI CULTURAL;
MULTI CULTURALLY; MULTICULTURAL; MULTICULTURALLY; PROMOTE DIVERSITY; PROMOTING DIVERSITY;
SEGREGATED CULTURES; SOCIAL ACTIVISM; SOCIAL ACTIVIST; SOCIAL ACTIVISTS; SOCIAL ADVOCACY; SOCIAL
ADVOCATE; SOCIAL BIAS; SOCIAL BIASES; SOCIAL INEQUALITIES; SOCIAL INEQUALITY; SOCIAL INEQUITIES;
SOCIAL INEQUITY; SOCIAL INJUSTICE; SOCIAL INJUSTICES; SOCIAL JUSTICE; SOCIAL JUSTICE ACTIVISM; SOCIAL
JUSTICE ADVOCACY; SOCIAL JUSTICE ADVOCATE; SOCIALLY BIASED; SOCIO CULTURAL; SOCIO CULTURALLY;
SOCIOCULTURAL; SOCIOCULTURALLY; STRUCTURAL INEQUALITY; STRUCTURAL INEQUITY; SUPPORT DIVERSITY;
SUPPORTING DIVERSITY; TRANS CULTURAL; TRANSCULTURAL; SOCIALLY RELEVANT; CULTURALLY RELEVANT
'''

genderbanstring='''
BIGOT; BIGOTRY; BLACK FEMALE; BLACK FEMALES; BLACK MALE; BLACK MALES; BLACK MEN; BLACK WOMEN;
CISGENDER; CISNORMATIVE; CISNORMATIVITY; COLORED FEMALE; COLORED FEMALES; COLORED MALE;
COLORED MALES; COLORED MEN; COLORED WOMEN; FEMALE; FEMALE VOICES; FEMALES; FEMININITY;
FEMINISM; FEMINIST; FEMINISTIC; FLUID IDENTITY; GENDER; GENDER ACCEPTANCE; GENDER AFFIRMATION;
GENDER AFFIRMING; GENDER AND SEXUAL; GENDER APPRECIATION; GENDER BASED; GENDER BINARY; GENDER
DISCRIMINATION; GENDER DISPARITIES; GENDER DISPARITY; GENDER DIVERSITY; GENDER DYSMORPHIA; GENDER
DYSPHORIA; GENDER FLUID; GENDER FLUIDITY; GENDER IDENTITY; GENDER IDEOLOGY; GENDER INCLUSIVE;
GENDER INCLUSIVITY; GENDER MARGINALIZED; GENDER MINORITIES; GENDER MINORITY; GENDER NEURAL;
GENDER NON BINARY; GENDER NON CONFORMING; GENDER NONBINARY; GENDER NONCONFORMING;
GENDER OPPRESSION; GENDER PREFERENCE; GENDER PREFERENCES; GENDER SPECTRUM; GENDER
STEREOTYPES; GENDER TRANSITION; GENDER TRANSITIONING; GENDER TYPICAL; GENDERS; HETEROSEXUAL;
HISPANIC FEMALE; HISPANIC FEMALES; HISPANIC MALE; HISPANIC MALES; HISPANIC MEN; HISPANIC WOMEN;
HISTORICALLY MALE; INDIGENOUS FEMALE; INDIGENOUS FEMALES; INDIGENOUS MALE; INDIGENOUS MALES;
INDIGENOUS MEN; INDIGENOUS WOMEN; INTERSECTIONAL FEMINISM; LATINA FEMALE; LATINA FEMALES; LATINA
MALE; LATINA MALES; LATINA MEN; LATINA WOMEN; LATINX FEMALE; LATINX FEMALES; LATINX MALE; LATINX
MALES; LATINX MEN; LATINX WOMEN; LGBT; LGBTQ; LGBTQ+; LGBTQIA; MALE DOMINANT; MALE
DOMINATED; MASCULINE; MASCULINITY; MIS GENDER; MISGENDER; MISOGYNISTIC; MISOGYNY; NON BINARY;
NON BINARY GENDER; NON CONFORMING GENDER; NONBINARY; NONBINARY GENDER; NONCONFORMING
GENDER; OPPRESSED GENDER; OPPRESSED GENDERS; OPPRESSED SEXUALITIES; PANSEXUAL; PREDOMINATELY
MALE; PREFERRED GENDER; PREFERRED IDENTITY; PREFERRED SEX; PRIMARILY MALE; PRONOUN; PRONOUNS;
QUEER THEORY; SELF IDENTIFY; SEX CHANGE; SEX PREFERENCE; SEX TRANSITION; SEXISM; SEXIST; SEXUAL
DISCRIMINATION; SEXUAL DISPARITIES; SEXUAL DISPARITY; SEXUAL IDENTITY; SEXUAL MINORITIES; SEXUAL
MINORITY; SEXUAL PREFERENCE; SEXUAL PREFERENCES; SEXUALITIES; SEXUALITY; STRAIGHT WHITE; TOXIC
MASCULINITY; TRANSGENDER; TRANSGENDERISM; TRANSITIONING GENDER; TRANSITIONING SEX; TRANSJUSTICE;
TRANSPHOBIA; TRANSPHOBIC; UNDERREPRESENTED GENDER; VOICES OF WOMEN; WHITE FEMALE; WHITE
FEMALES; WHITE MALE; WHITE MALES; WHITE MEN; WHITE WOMEN; WOMEN; WOMEN AND GENDER;
WOMEN AND UNDERREPRESENTED; WOMENUNDERREPRESENTED
'''
racebanstring='''
ANTI BLACK; ANTI BLACK RACISM; ANTI RACISM; ANTI RACIST; ANTI WHITE; ANTIBLACK; ANTIBLACK RACISM;
ANTIRACISM; ANTIRACIST; ANTIWHITE; BIPOC; BIPOCX; BLACK AND LATINX; BLACK COMMUNITIES; BLACK
COMMUNITY; BLACK INDIGENOUS AND LATINX; BLACK INDIGENOUS AND OTHER; BLACK INDIGENOUS LATINX;
BLACK INDIGENOUS OTHER; BLACK INDIVIDUAL; BLACK INDIVIDUALS; BLACK INTELLECTUALISM; BLACK LIVES
MATTER; BLACK MINORITIES; BLACK MINORITY; BLACK PEOPLE; BLACK PERSON; BLACK THOUGHT; BLACK
VOICES; BLACKNESS; COLORED COMMUNITIES; COLORED COMMUNITY; COLORED INDIVIDUAL; COLORED
INDIVIDUALS; COLORED MINORITIES; COLORED MINORITY; COLORED PEOPLE; COLORED PERSON; COLORED
VOICES; CRITICAL RACE THEORY; ETHNIC AND RACIAL; ETHNIC BIAS; ETHNIC COMMUNITIES; ETHNIC
COMMUNITY; ETHNIC IDENTITIES; ETHNIC IDENTITY; ETHNIC INDIVIDUAL; ETHNIC INDIVIDUALS; ETHNIC
MINORITIES; ETHNIC MINORITY; ETHNIC PEOPLE; ETHNIC PERSON; ETHNIC RACISM; ETHNIC SEGREGATION;
ETHNIC VOICES; ETHNICAL RACISM; ETHNICITIES AND RACES; ETHNICITY; ETHNICITY AND RACE; HISPANIC
COMMUNITIES; HISPANIC COMMUNITY; HISPANIC INDIVIDUAL; HISPANIC INDIVIDUALS; HISPANIC MINORITIES;
HISPANIC MINORITY; HISPANIC PEOPLE; HISPANIC PERSON; HISPANIC VOICES; HISTORICAL RACISM;
HISTORICALLY RACIST; HISTORICALLY WHITE; INDIGENOUS COMMUNITIES; INDIGENOUS COMMUNITY;
INDIGENOUS INDIVIDUAL; INDIGENOUS INDIVIDUALS; INDIGENOUS MINORITIES; INDIGENOUS MINORITY;
INDIGENOUS PEOPLE; INDIGENOUS PERSON; INDIGENOUS VOICES; INSTITUTIONAL RACISM; INSTITUTIONALIZED
RACISM; INSTITUTIONALLY RACIST; INTER RACIAL; INTER RACIALLY; INTERRACIAL; INTERRACIALLY; LATINA
COMMUNITIES; LATINA COMMUNITY; LATINA INDIVIDUAL; LATINA INDIVIDUALS; LATINA MINORITIES; LATINA
MINORITY; LATINA PEOPLE; LATINA PERSON; LATINA VOICES; LATINX COMMUNITIES; LATINX COMMUNITY;
LATINX INDIVIDUAL; LATINX INDIVIDUALS; LATINX MINORITIES; LATINX MINORITY; LATINX PEOPLE; LATINX
PERSON; LATINX VOICES; MULTI ETHNIC; MULTI ETHNICALLY; MULTIETHNIC; MULTIETHNICALLY; NON BLACK;
NON WHITE; NONBLACK; NONWHITE; PEOPLE OF COLOR; POC; POCX; PREDOMINATELY WHITE; PRIMARILY
WHITE; PRIVILEGED WHITE; PRO BLACK; PRO WHITE; PROBLACK; PROWHITE; RACE AND CULTURE; RACE AND
ETHNICITY; RACE BASED; RACEBASED; RACES AND CULTURES; RACES AND ETHNICITIES; RACIAL; RACIAL AND
CULTURAL; RACIAL AND ETHNIC; RACIAL BIAS; RACIAL BIASES; RACIAL DISPARITIES; RACIAL DISPARITY; RACIAL
DIVERSITY; RACIAL IDENTITY; RACIAL INEQUALITIES; RACIAL INEQUALITY; RACIAL INEQUITIES; RACIAL INEQUITY;
RACIAL INJUSTICE; RACIAL INJUSTICES; RACIAL JUSTICE; RACIAL MINORITIES; RACIAL MINORITY; RACIAL
OPPRESSION; RACIAL PREJUDICE; RACIAL PREJUDICES; RACIAL SEGREGATION; RACIAL SOCIALIZATION; RACIAL
SOLIDARITY; RACIAL STEREOTYPES; RACIAL VIOLENCE; RACIALLY; RACIALLY AND CULTURALLY; RACIALLY BIAS;
RACIALLY BIASED; RACIALLY OPPRESSED; RACISM; RACIST; SEGREGATED ETHNICITIES; SEGREGATED ETHNICITY;
SEGREGATED RACE; SEGREGATED RACES; STRUCTURAL RACISM; STRUCTURALLY RACIST; SYSTEMIC RACISM;
SYSTEMICALLY RACIST; TOKENISTIC; TOKENSIM; TRANS ETHNIC; TRANSETHNIC; WHITE COLONIALISM; WHITE
COLONIZATION; WHITE COLONIZER; WHITE COLONIZERS; WHITE FRAGILITY; WHITE HISTORICALLY; WHITE
NATIONALISM; WHITE NATIONALIST; WHITE PEOPLE; WHITE PERSON; WHITE PRIVILEGE; WHITE SERVING; WHITE
SUPREMACY; WHITENESS.
'''

environmentaljusticebanstring='''
CLIMATE ACTION; CLIMATE CONSCIOUS; CLIMATE CONSCIOUSNESS; CLIMATE EQUALITY; CLIMATE EQUITY;
CLIMATE JUSTICE; CLIMATE RESEARCH; ECO CULTURAL; ECOCULTURAL; ENVIRONMENT CONSCIOUS;
ENVIRONMENT CONSCIOUSNESS; ENVIRONMENTAL CONSCIOUS; ENVIRONMENTAL CONSCIOUSNESS;
ENVIRONMENTAL EQUALITY; ENVIRONMENTAL EQUITY; ENVIRONMENTAL GOVERNANCE; ENVIRONMENTAL JUSTICE;
ENVIRONMENTAL SOCIAL; ENVIRONMENTALGOVERNANCE; ENVIRONMENTALLY CONSCIOUS;
ENVIRONMENTALSOCIAL; ESG; ESG EFFORT; ESG EFFORTS; ESG INITIATIVE; ESG INITIATIVES; GREEN NEW
DEAL; NET ZERO; NETZERO; SOCIAL ENVIRONMENTAL; SOCIALENVIRONMENTAL; CLIMATE INJUSTICE; CLIMATE
JUSTICES; CLIMATE INJUSTICES; CLIMATE CHANGE; GREEN INFRASTRUCTURE; GREEN SOCIETY; CLEAN ENERGY.
'''

# %%
all_bans = [statusbanstring, socialbanstring, genderbanstring, racebanstring, environmentaljusticebanstring]


all_terms = []

for terms_str in all_bans:
    lis = terms_str.replace('\n','').replace('.','').split(';')
    lis = [i.lower().strip() for i in lis]
    
    all_terms += lis

senate_terms = set(all_terms)

len(senate_terms)
# Out:
# 695

# %% [markdown]
# Senate terms cover more words, but the scope of the other flagged terms is likely different.

# %%
senate_terms
# Out:
# {'activism',
#  'activist',
#  'activists',
#  'advance diversity',
#  'advance inclusivity',
#  'advance the diversity',
#  'advancing diversity',
#  'advancing inclusive',
#  'advocacy',
#  'advocate',
#  'advocates',
#  'affirmative action',
#  'alliance for diversity',
#  'ally',
#  'allyship',
#  'anti black',
#  'anti black racism',
#  'anti racism',
#  'anti racist',
#  'anti white',
#  'antiblack',
#  'antiblack racism',
#  'antiracism',
#  'antiracist',
#  'antiwhite',
#  'background inclusivity',
#  'barrier',
#  'barriers',
#  'bi cultural',
#  'bias toward',
#  'bias towards',
#  'biased',
#  'biased toward',
#  'biased towards',
#  'biases',
#  'biases toward',
#  'biases towards',
#  'bicultural',
#  'bigot',
#  'bigotry',
#  'bipoc',
#  'bipocx',
#  'black and latinx',
#  'black communities',
#  'black cultural',
#  'black culture',
#  'black cultures',
#  'black female',
#  'black females',
#  'black indigenous and latinx',
#  'black indigenous and other',
#  'black indigenous latinx',
#  'black indigenous other',
#  'black individual',
#  'black individuals',
#  'black intellectualism',
#  'black livesmatter',
#  'black male',
#  'black males',
#  'black men',
#  'black minorities',
#  'black minority',
#  'black people',
#  'black person',
#  'black thought',
#  'black women',
#  'blackcommunity',
#  'blackness',
#  'blackvoices',
#  'broaden diversity',
#  'broaden the diversity',
#  'cisgender',
#  'cisnormative',
#  'cisnormativity',
#  'clean energy',
#  'climate action',
#  'climate change',
#  'climate conscious',
#  'climate consciousness',
#  'climate equality',
#  'climate equity',
#  'climate injustice',
#  'climate injustices',
#  'climate justice',
#  'climate research',
#  'climatejustices',
#  'colored communities',
#  'colored community',
#  'colored female',
#  'colored females',
#  'colored individual',
#  'colored male',
#  'colored males',
#  'colored men',
#  'colored minorities',
#  'colored minority',
#  'colored people',
#  'colored person',
#  'colored women',
#  'coloredindividuals',
#  'coloredvoices',
#  'commitment to diversity',
#  'community diversity',
#  'community equity',
#  'community inclusivity',
#  'critical race theory',
#  'cultural activism',
#  'cultural activists',
#  'cultural advocacy',
#  'cultural advocate',
#  'cultural and ethnic',
#  'cultural and racial',
#  'cultural appropriation',
#  'cultural appropriations',
#  'cultural bias',
#  'cultural connections',
#  'cultural differences',
#  'cultural heritage',
#  'cultural humility',
#  'cultural inequalities',
#  'cultural inequality',
#  'cultural inequities',
#  'cultural inequity',
#  'cultural injustices',
#  'cultural justice',
#  'cultural relevance',
#  'cultural segregation',
#  'culturalactivist',
#  'culturalcompetency',
#  'culturalinjustice',
#  'culturally attuned',
#  'culturally biased',
#  'culturally relevant',
#  'culturally responsive',
#  'culturally sensitive',
#  'culturally sustaining',
#  'culturallysustainable',
#  'culture and ethnicity',
#  'culture and race',
#  'cultures and races',
#  'cultures andethnicities',
#  'de colonize',
#  'de colonized',
#  'de colonizing',
#  'de segregate',
#  'de segregated',
#  'de segregation',
#  'decolonization',
#  'decolonize',
#  'decolonized',
#  'decolonizing',
#  'dei',
#  'deij',
#  'desegregate',
#  'desegregated',
#  'desegregates',
#  'desegregation',
#  'disabilities',
#  'disability',
#  'discriminate',
#  'discriminated',
#  'discrimination',
#  'discriminatory',
#  'diverse background',
#  'diverse backgrounds',
#  'diverse community',
#  'diverse group',
#  'diverse groups',
#  'diverse individual',
#  'diverse status',
#  'diverse statuses',
#  'diverse voices',
#  'diversecommunities',
#  'diverseindividuals',
#  'diversified',
#  'diversify',
#  'diversifying',
#  'diversity and equity',
#  'diversity and inclusion',
#  'diversity and inclusivity',
#  'diversity awareness',
#  'diversity equity',
#  'divisiveness',
#  'eco cultural',
#  'ecocultural',
#  'emphasis on diversity',
#  'emphasize diversity',
#  'emphasizing diversity',
#  'encouragediversity',
#  'encouraging diversity',
#  'enhance diversity',
#  'enhance the diversity',
#  'enhancing diversity',
#  'environment conscious',
#  'environment consciousness',
#  'environmental conscious',
#  'environmental consciousness',
#  'environmental equality',
#  'environmental equity',
#  'environmental governance',
#  'environmental justice',
#  'environmental social',
#  'environmentalgovernance',
#  'environmentally conscious',
#  'environmentalsocial',
#  'equal opportunities',
#  'equal opportunity',
#  'equalities',
#  'equality',
#  'equitable',
#  'equitable and inclusive',
#  'equities',
#  'equity',
#  'esg',
#  'esg effort',
#  'esg efforts',
#  'esg initiative',
#  'esg initiatives',
#  'ethnic and cultural',
#  'ethnic and racial',
#  'ethnic bias',
#  'ethnic communities',
#  'ethnic cultural',
#  'ethnic culture',
#  'ethnic cultures',
#  'ethnic equity',
#  'ethnic identities',
#  'ethnic identity',
#  'ethnic individual',
#  'ethnic individuals',
#  'ethnic minority',
#  'ethnic people',
#  'ethnic person',
#  'ethnic racism',
#  'ethnic segregation',
#  'ethnic voices',
#  'ethnical racism',
#  'ethniccommunity',
#  'ethnicdiversity',
#  'ethnicities and cultures',
#  'ethnicities and races',
#  'ethnicity',
#  'ethnicity and culture',
#  'ethnicity and race',
#  'ethnicminorities',
#  'excluded',
#  'exclusion',
#  'exclusive',
#  'feel seen and heard',
#  'female',
#  'female voices',
#  'females',
#  'femininity',
#  'feminism',
#  'feminist',
#  'feministic',
#  'fluid identity',
#  'foster diversity',
#  'fostering diversity',
#  'fostering inclusive',
#  'fostering inclusivity',
#  'fostering the diversity',
#  'gender',
#  'gender acceptance',
#  'gender affirmation',
#  'gender affirming',
#  'gender and sexual',
#  'gender appreciation',
#  'gender based',
#  'gender binary',
#  'gender disparities',
#  'gender disparity',
#  'gender diversity',
#  'gender dysmorphia',
#  'gender fluid',
#  'gender fluidity',
#  'gender identity',
#  'gender ideology',
#  'gender inclusive',
#  'gender inclusivity',
#  'gender marginalized',
#  'gender minorities',
#  'gender minority',
#  'gender neural',
#  'gender non binary',
#  'gender non conforming',
#  'gender nonbinary',
#  'gender nonconforming',
#  'gender oppression',
#  'gender preference',
#  'gender preferences',
#  'gender spectrum',
#  'gender transition',
#  'gender transitioning',
#  'gender typical',
#  'genderdiscrimination',
#  'genderdysphoria',
#  'genders',
#  'genderstereotypes',
#  'green infrastructure',
#  'green newdeal',
#  'green society',
#  'group inclusivity',
#  'groupequity',
#  'hate speech',
#  'heterosexual',
#  'hispanic community',
#  'hispanic cultural',
#  'hispanic culture',
#  'hispanic cultures',
#  'hispanic female',
#  'hispanic females',
#  'hispanic individual',
#  'hispanic individuals',
#  'hispanic male',
#  'hispanic males',
#  'hispanic men',
#  'hispanic minorities',
#  'hispanic minority',
#  'hispanic people',
#  'hispanic person',
#  'hispanic voices',
#  'hispanic women',
#  'hispaniccommunities',
#  'historical racism',
#  'historically',
#  'historically male',
#  'historically racist',
#  'historically white',
#  'implicit bias',
#  'implicit biases',
#  'inclusion',
#  'inclusive',
#  'inclusive language',
#  'inclusiveness',
#  'inclusivity',
#  'inclusivity and diversity',
#  'increase diversity',
#  'increase the diversity',
#  'increases diversity',
#  'increases the diversity',
#  'increasing diversity',
#  'increasingthe diversity',
#  'indigenous communities',
#  'indigenous community',
#  'indigenous cultural',
#  'indigenous culture',
#  'indigenous cultures',
#  'indigenous female',
#  'indigenous females',
#  'indigenous individual',
#  'indigenous individuals',
#  'indigenous male',
#  'indigenous males',
#  'indigenous men',
#  'indigenous minorities',
#  'indigenous minority',
#  'indigenous people',
#  'indigenous person',
#  'indigenous voices',
#  'indigenous women',
#  'inequalities',
#  'inequality',
#  'inequitable',
#  'inequities',
#  'inequity',
#  'injustice',
#  'injustices',
#  'institutional',
#  'institutional racism',
#  'institutionalize',
#  'institutionalized',
#  'institutionalizedracism',
#  'institutionally',
#  'institutionally racist',
#  'inter cultural',
#  'inter culturally',
#  'inter racial',
#  'inter racially',
#  'intercultural',
#  'interculturally',
#  'intergenerational trauma',
#  'interracial',
#  'interracially',
#  'intersectional',
#  'intersectional feminism',
#  'intersectionality',
#  'lack of diversity',
#  'latina community',
#  'latina female',
#  'latina females',
#  'latina individual',
#  'latina individuals',
#  'latina males',
#  'latina men',
#  'latina minorities',
#  'latina people',
#  'latina person',
#  'latina voices',
#  'latina women',
#  'latinacommunities',
#  'latinamale',
#  'latinaminority',
#  'latinx communities',
#  'latinx community',
#  'latinx cultural',
#  'latinx culture',
#  'latinx cultures',
#  'latinx female',
#  'latinx females',
#  'latinx individual',
#  'latinx individuals',
#  'latinx male',
#  'latinx men',
#  'latinx minorities',
#  'latinx minority',
#  'latinx people',
#  'latinx voices',
#  'latinx women',
#  'latinxmales',
#  'latinxperson',
#  'lgbt',
#  'lgbtq',
#  'lgbtq+',
#  'lgbtqia',
#  'male dominant',
#  'maledominated',
#  'marginalization',
#  'marginalize',
#  'marginalized',
#  'masculine',
#  'masculinity',
#  'micro aggression',
#  'micro aggressive',
#  'micro aggressiveness',
#  'microaggression',
#  'microaggressions',
#  'microaggressive',
#  'microaggressiveness',
#  'minorities',
#  'minority',
#  'mis gender',
#  'misgender',
#  'misogynistic',
#  'misogyny',
#  'multi cultural',
#  'multi culturally',
#  'multi ethnic',
#  'multi ethnically',
#  'multicultural',
#  'multiculturally',
#  'multiethnic',
#  'multiethnically',
#  'net zero',
#  'netzero',
#  'non binary',
#  'non binary gender',
#  'non black',
#  'non conforming gender',
#  'non white',
#  'nonbinary',
#  'nonbinary gender',
#  'nonblack',
#  'nonconforminggender',
#  'nonwhite',
#  'oppressed',
#  'oppressed gender',
#  'oppressed genders',
#  'oppressed sexualities',
#  'oppression',
#  'oppressive',
#  'oppressiveness',
#  'pansexual',
#  'people of color',
#  'poc',
#  'pocx',
#  'polarization',
#  'polarize',
#  'political',
#  'politicization',
#  'politicize',
#  'predominately white',
#  'predominatelymale',
#  'preferred gender',
#  'preferred identity',
#  'preferred sex',
#  'prejudice',
#  'prejudices',
#  'primarily male',
#  'primarilywhite',
#  'privilege',
#  'privileged',
#  'privileged white',
#  'privileges',
#  'pro black',
#  'pro white',
#  'problack',
#  'promote diversity',
#  'promoting diversity',
#  'pronoun',
#  'pronouns',
#  'prowhite',
#  'queer theory',
#  'race and culture',
#  'race andethnicity',
#  'race based',
#  'racebased',
#  'races and cultures',
#  'races and ethnicities',
#  'racial',
#  'racial and ethnic',
#  'racial andcultural',
#  'racial bias',
#  'racial biases',
#  'racial disparities',
#  'racial disparity',
#  'racial identity',
#  'racial inequalities',
#  'racial inequality',
#  'racial inequities',
#  'racial inequity',
#  'racial injustice',
#  'racial injustices',
#  'racial justice',
#  'racial minorities',
#  'racial minority',
#  'racial prejudice',
#  'racial prejudices',
#  'racial segregation',
#  'racial socialization',
#  'racial stereotypes',
#  'racial violence',
#  'racialdiversity',
#  'racially',
#  'racially and culturally',
#  'racially bias',
#  'racially biased',
#  'racially oppressed',
#  'racialoppression',
#  'racialsolidarity',
#  'racism',
#  'racist',
#  'reparation',
#  'reparations',
#  'safe space',
#  'safe spaces',
#  'segregated',
#  'segregated cultures',
#  'segregated ethnicities',
#  'segregated ethnicity',
#  'segregated race',
#  'segregated races',
#  'segregation',
#  'self identify',
#  'sense of belongingness',
#  'sense ofbelonging',
#  'sex change',
#  'sex preference',
#  'sex transition',
#  'sexism',
#  'sexist',
#  'sexual disparities',
#  'sexual disparity',
#  'sexual identity',
#  'sexual minorities',
#  'sexual preference',
#  'sexual preferences',
#  'sexualdiscrimination',
#  'sexualities',
#  'sexuality',
#  'sexualminority',
#  'social activism',
#  'social activist',
#  'social activists',
#  'social advocacy',
#  'social bias',
#  'social biases',
#  'social environmental',
#  'social inequalities',
#  'social inequality',
#  'social inequities',
#  'social inequity',
#  'social injustice',
#  'social injustices',
#  'social justice',
#  'social justice activism',
#  'social justice advocate',
#  'socialadvocate',
#  'socialenvironmental',
#  'socialjustice advocacy',
#  'socially biased',
#  'socially relevant',
#  'socio cultural',
#  'socio culturally',
#  'socio economic',
#  'sociocultural',
#  'socioculturally',
#  'socioeconomic',
#  'status',
#  'statuses',
#  'stereotype',
#  'stereotypes',
#  'stereotypical',
#  'stereotyping',
#  'straight white',
#  'structural inequality',
#  'structural inequity',
#  'structural racism',
#  'structurally racist',
#  'support diversity',
#  'supporting diversity',
#  'system of oppression',
#  'systematic oppression',
#  'systematically oppressed',
#  'systemic',
#  'systemic oppression',
#  'systemic racism',
#  'systemical',
#  'systemically',
#  'systemically oppressed',
#  'systemically racist',
#  'systems of oppression',
#  'systems of power',
#  'tokenistic',
#  'tokensim',
#  'toxicmasculinity',
#  'trans cultural',
#  'trans ethnic',
#  'transcultural',
#  'transethnic',
#  'transgender',
#  'transgenderism',
#  'transitioning gender',
#  'transitioning sex',
#  'transjustice',
#  'transphobia',
#  'transphobic',
#  'trauma',
#  'traumatic',
#  'under appreciated',
#  'under appreciation',
#  'under privilege',
#  'under privileged',
#  'under representation',
#  'under represented',
#  'under served',
#  'under serving',
#  'under valuing',
#  'underappreciated',
#  'underappreciation',
#  'underprivilege',
#  'underprivileged',
#  'underrepresentation',
#  'underrepresented',
#  'underrepresented gender',
#  'underserved',
#  'underserving',
#  'undervalued',
#  'undervaluing',
#  'unequal opportunities',
#  'unequal opportunity',
#  'unjust',
#  'victim',
#  'victimhood',
#  'victimized',
#  'victims',
#  'voices are acknowledged',
#  'voices heard',
#  'voices of women',
#  'voicesmatter',
#  'welcoming environment',
#  'white colonialism',
#  'white colonizer',
#  'white colonizers',
#  'white female',
#  'white fragility',
#  'white historically',
#  'white male',
#  'white males',
#  'white men',
#  'white nationalist',
#  'white people',
#  'white person',
#  'white privilege',
#  'white serving',
#  'white women',
#  'whitecolonization',
#  'whitefemales',
#  'whitenationalism',
#  'whiteness',
#  'whitesupremacy',
#  'women',
#  'women and gender',
#  'women and underrepresented',
#  'womenunderrepresented'}

# %%
flagged_new
# Out:
# {'accessible',
#  'activism',
#  'activists',
#  'advocacy',
#  'advocate',
#  'advocates',
#  'affirming care',
#  'allyship',
#  'anti-racism',
#  'antiracist',
#  'assigned at birth',
#  'assigned female at birth',
#  'assigned male at birth',
#  'at risk',
#  'barrier',
#  'barriers',
#  'belong',
#  'bias',
#  'biased',
#  'biased toward',
#  'biases',
#  'biases towards',
#  'bipoc',
#  'black',
#  'climate science',
#  'community diversity',
#  'cultural competence',
#  'cultural differences',
#  'cultural sensitivity',
#  'culturally appropriate',
#  'culturally responsive',
#  'dei',
#  'deia',
#  'disabilities',
#  'disability',
#  'discriminated',
#  'discrimination',
#  'discriminatory',
#  'disparity',
#  'diverse',
#  'diverse backgrounds',
#  'diverse communities',
#  'diverse community',
#  'diverse group',
#  'diverse groups',
#  'diversified',
#  'diversify',
#  'diversifying',
#  'diversity',
#  'enhance the diversity',
#  'enhancing diversity',
#  'equality',
#  'equitable',
#  'equity',
#  'ethnicity',
#  'excluded',
#  'exclusion',
#  'expression',
#  'female',
#  'females',
#  'gender',
#  'gender based',
#  'gender diversity',
#  'gender identity',
#  'gender-affirming care',
#  'genders',
#  'hate speech',
#  'health disparity',
#  'health equity',
#  'hesitancy',
#  'hesitant',
#  'historically',
#  'identity',
#  'immigrants',
#  'implicit bias',
#  'implicit biases',
#  'inclusion',
#  'inclusive',
#  'inclusiveness',
#  'inclusivity',
#  'increase diversity',
#  'increase the diversity',
#  'indigenous community',
#  'inequalities',
#  'inequality',
#  'inequitable',
#  'inequities',
#  'inequity',
#  'injustice',
#  'institutional',
#  'intersectional',
#  'intersectionality',
#  'key groups',
#  'key populations',
#  'latinx',
#  'lgbt',
#  'lgbtq',
#  'marginalize',
#  'marginalized',
#  'men who have sex with men',
#  'mental health',
#  'minorities',
#  'minority',
#  'most risk',
#  'mrna',
#  'msm',
#  'multicultural',
#  'mx',
#  'native american',
#  'non-binary',
#  'nonbinary',
#  'oppression',
#  'oppressive',
#  'orientation',
#  'person-centered',
#  'person-centered care',
#  'polarization',
#  'political',
#  'pollution',
#  'pregnant people',
#  'pregnant person',
#  'pregnant persons',
#  'prejudice',
#  'privilege',
#  'promote diversity',
#  'promoting diversity',
#  'pronoun',
#  'race',
#  'race and ethnicity',
#  'racial',
#  'racial diversity',
#  'racial identity',
#  'racial inequality',
#  'racial justice',
#  'racially',
#  'racism',
#  'segregation',
#  'sense of belonging',
#  'sex',
#  'sexuality',
#  'social justice',
#  'sociocultural',
#  'socioeconomic',
#  'status',
#  'stereotype',
#  'stereotypes',
#  'systemic',
#  'systemically',
#  'trans',
#  'transgender',
#  'trauma',
#  'traumatic',
#  'tribal',
#  'underappreciated',
#  'underprivileged',
#  'underrepresentation',
#  'underrepresented',
#  'underserved',
#  'vaccinate',
#  'vaccination',
#  'vaccine',
#  'vaccines',
#  'victim',
#  'victims',
#  'vulnerable populations',
#  'women',
#  'women and underrepresented'}

# %%
diff = list(senate_terms - flagged_new)
diff
# Out:
# ['gender nonbinary',
#  'increasingthe diversity',
#  'sexual identity',
#  'gender affirmation',
#  'segregated',
#  'gender transition',
#  'preferred sex',
#  'ethnic equity',
#  'decolonizing',
#  'gender non conforming',
#  'diverseindividuals',
#  'privileged white',
#  'climate consciousness',
#  'anti racism',
#  'latinxperson',
#  'colored minority',
#  'anti white',
#  'institutionalized',
#  'underprivilege',
#  'increases the diversity',
#  'indigenous men',
#  'sexualities',
#  'bigot',
#  'race and culture',
#  'pro white',
#  'de segregated',
#  'racial inequities',
#  'indigenous female',
#  'hispanic male',
#  'ethnicities and races',
#  'cisnormative',
#  'group inclusivity',
#  'underrepresented gender',
#  'inter racial',
#  'pansexual',
#  'hispanic voices',
#  'historical racism',
#  'gender appreciation',
#  'systemic oppression',
#  'misogyny',
#  'racially and culturally',
#  'antiwhite',
#  'transphobic',
#  'non conforming gender',
#  'enhance diversity',
#  'colored males',
#  'latina men',
#  'white serving',
#  'esg efforts',
#  'green newdeal',
#  'colored females',
#  'ethnicdiversity',
#  'gender acceptance',
#  'latinx people',
#  'cultural appropriation',
#  'under valuing',
#  'ethnic voices',
#  'gender typical',
#  'supporting diversity',
#  'under privileged',
#  'hispanic minorities',
#  'cultural inequities',
#  'femininity',
#  'cisnormativity',
#  'tokenistic',
#  'womenunderrepresented',
#  'advancing diversity',
#  'support diversity',
#  'welcoming environment',
#  'indigenous individual',
#  'social injustice',
#  'diversity awareness',
#  'groupequity',
#  'cultural appropriations',
#  'environmental social',
#  'cultural and ethnic',
#  'multi ethnic',
#  'under appreciated',
#  'under representation',
#  'diverse background',
#  'indigenous male',
#  'structurally racist',
#  'marginalization',
#  'equal opportunity',
#  'poc',
#  'indigenous minority',
#  'socio culturally',
#  'race andethnicity',
#  'colored communities',
#  'hispanic people',
#  'predominatelymale',
#  'environmental governance',
#  'cultural relevance',
#  'heterosexual',
#  'colored individual',
#  'racially biased',
#  'system of oppression',
#  'indigenous minorities',
#  'segregated cultures',
#  'cultural humility',
#  'predominately white',
#  'micro aggressive',
#  'undervaluing',
#  'cultural inequality',
#  'culturally sensitive',
#  'latinx individuals',
#  'latina person',
#  'racist',
#  'black indigenous and other',
#  'colored community',
#  'ethnic identities',
#  'latinx male',
#  'racial prejudice',
#  'gender inclusive',
#  'sexual minorities',
#  'white colonizers',
#  'cisgender',
#  'climate equity',
#  'blackcommunity',
#  'cultures and races',
#  'diverse statuses',
#  'desegregation',
#  'cultural bias',
#  'indigenous communities',
#  'problack',
#  'ethnic cultures',
#  'indigenous culture',
#  'social inequalities',
#  'underappreciation',
#  'underserving',
#  'prowhite',
#  'non black',
#  'historically white',
#  'diversity and inclusion',
#  'non white',
#  'gender minority',
#  'white men',
#  'sex preference',
#  'environmental equality',
#  'lack of diversity',
#  'microaggression',
#  'indigenous individuals',
#  'racial disparity',
#  'desegregated',
#  'culturally sustaining',
#  'culture and ethnicity',
#  'ethnicities and cultures',
#  'colored people',
#  'de colonized',
#  'reparation',
#  'systemically racist',
#  'racebased',
#  'inter cultural',
#  'desegregate',
#  'diversity and equity',
#  'fostering the diversity',
#  'male dominant',
#  'racially oppressed',
#  'culturalinjustice',
#  'ethnicity and race',
#  'oppressed sexualities',
#  'safe space',
#  'esg',
#  'black culture',
#  'cultural segregation',
#  'non binary gender',
#  'hispanic minority',
#  'microaggressive',
#  'cultural justice',
#  'masculine',
#  'misgender',
#  'whitesupremacy',
#  'esg initiatives',
#  'ethnic minority',
#  'cultural heritage',
#  'colored men',
#  'self identify',
#  'culturally relevant',
#  'gender non binary',
#  'de segregation',
#  'voices of women',
#  'indigenous males',
#  'voicesmatter',
#  'antiracism',
#  'gender dysmorphia',
#  'blackvoices',
#  'latinx females',
#  'bias toward',
#  'black thought',
#  'socialjustice advocacy',
#  'microaggressions',
#  'under serving',
#  'advance the diversity',
#  'stereotypical',
#  'pro black',
#  'toxicmasculinity',
#  'racially bias',
#  'races and cultures',
#  'climate action',
#  'polarize',
#  'sexual preferences',
#  'black individuals',
#  'environmental justice',
#  'sexualdiscrimination',
#  'latina females',
#  'hispanic female',
#  'politicization',
#  'social environmental',
#  'community equity',
#  'indigenous person',
#  'feminist',
#  'broaden diversity',
#  'blackness',
#  'social biases',
#  'multiethnic',
#  'races and ethnicities',
#  'exclusive',
#  'social justice activism',
#  'intercultural',
#  'fostering inclusive',
#  'racialdiversity',
#  'ethnic and racial',
#  'indigenous cultures',
#  'under served',
#  'indigenous cultural',
#  'latina people',
#  'racial violence',
#  'pronouns',
#  'multiculturally',
#  'whiteness',
#  'colored women',
#  'bicultural',
#  'anti black racism',
#  'transethnic',
#  'racial injustices',
#  'structural racism',
#  'socio economic',
#  'interracially',
#  'people of color',
#  'commitment to diversity',
#  'culturally attuned',
#  'hispanic individual',
#  'segregated ethnicity',
#  'reparations',
#  'gender fluidity',
#  'ethnic person',
#  'cultural advocacy',
#  'unjust',
#  'interracial',
#  'climate change',
#  'black intellectualism',
#  'culturallysustainable',
#  'black males',
#  'multi culturally',
#  'transcultural',
#  'racial bias',
#  'activist',
#  'white historically',
#  'indigenous females',
#  'increases diversity',
#  'latinx minority',
#  'latina minorities',
#  'white colonizer',
#  'advance inclusivity',
#  'cultural activists',
#  'gender fluid',
#  'antiblack',
#  'broaden the diversity',
#  'ecocultural',
#  'transgenderism',
#  'gender inclusivity',
#  'hispaniccommunities',
#  'latina voices',
#  'multi cultural',
#  'de segregate',
#  'black minority',
#  'colored person',
#  'climate injustice',
#  'white women',
#  'climate equality',
#  'black indigenous and latinx',
#  'segregated races',
#  'esg effort',
#  'racial disparities',
#  'institutionalizedracism',
#  'diversecommunities',
#  'social activism',
#  'social injustices',
#  'whitefemales',
#  'indigenous women',
#  'maledominated',
#  'pocx',
#  'under represented',
#  'esg initiative',
#  'encouragediversity',
#  'latinacommunities',
#  'queer theory',
#  'emphasis on diversity',
#  'politicize',
#  'affirmative action',
#  'hispanic men',
#  'latinx voices',
#  'institutionally racist',
#  'systems of oppression',
#  'climate injustices',
#  'socialenvironmental',
#  'sexual preference',
#  'nonconforminggender',
#  'black female',
#  'feminism',
#  'black people',
#  'antiblack racism',
#  'cultural inequalities',
#  'black indigenous other',
#  'black minorities',
#  'whitecolonization',
#  'prejudices',
#  'inclusive language',
#  'intergenerational trauma',
#  'social inequality',
#  'hispanic females',
#  'historically racist',
#  'injustices',
#  'voices are acknowledged',
#  'safe spaces',
#  'latinx female',
#  'black and latinx',
#  'advance diversity',
#  'social justice advocate',
#  'ethnic racism',
#  'transjustice',
#  'racial inequity',
#  'gender affirming',
#  'privileged',
#  'environment consciousness',
#  'hispanic males',
#  'white male',
#  'black cultures',
#  'oppressed gender',
#  'cultural activism',
#  'trans ethnic',
#  'net zero',
#  'white privilege',
#  'interculturally',
#  'sexism',
#  'cultures andethnicities',
#  'masculinity',
#  'under privilege',
#  'ethnic cultural',
#  'ethniccommunity',
#  'bipocx',
#  'structural inequality',
#  'fostering inclusivity',
#  'white colonialism',
#  'biased towards',
#  'racial minority',
#  'black cultural',
#  'black individual',
#  'latina community',
#  'de colonize',
#  'white nationalist',
#  'trans cultural',
#  'culturally biased',
#  'discriminate',
#  'latinaminority',
#  'nonbinary gender',
#  'latinx minorities',
#  'equal opportunities',
#  'socialadvocate',
#  'stereotyping',
#  'gender ideology',
#  'ethnic and cultural',
#  'black men',
#  'ethnic bias',
#  'institutional racism',
#  'latinx communities',
#  'socio cultural',
#  'mis gender',
#  'oppressed',
#  'latinx community',
#  'coloredindividuals',
#  'colored male',
#  'black communities',
#  'gender preference',
#  'latina individual',
#  'decolonized',
#  'background inclusivity',
#  'indigenous voices',
#  'encouraging diversity',
#  'environmentally conscious',
#  'eco cultural',
#  'fluid identity',
#  'latinx women',
#  'preferred identity',
#  'diversity and inclusivity',
#  'equitable and inclusive',
#  'sense ofbelonging',
#  'ally',
#  'preferred gender',
#  'white fragility',
#  'hispanic cultural',
#  'black person',
#  'segregated ethnicities',
#  'feel seen and heard',
#  'socioculturally',
#  'microaggressiveness',
#  'structural inequity',
#  'black male',
#  'inter culturally',
#  'decolonization',
#  'racialoppression',
#  'increasing diversity',
#  'unequal opportunity',
#  'institutionalize',
#  'latinx individual',
#  'black women',
#  'black females',
#  'black livesmatter',
#  'nonblack',
#  'historically male',
#  'alliance for diversity',
#  'sexual disparities',
#  'racial injustice',
#  'racial stereotypes',
#  'coloredvoices',
#  'green infrastructure',
#  'latinx men',
#  'micro aggressiveness',
#  'multiethnically',
#  'institutionally',
#  'diverse status',
#  'racial andcultural',
#  'racialsolidarity',
#  'race based',
#  'non binary',
#  'ethnicity and culture',
#  'gender marginalized',
#  'gender spectrum',
#  'diverse individual',
#  'advancing inclusive',
#  'gender transitioning',
#  'primarilywhite',
#  'transphobia',
#  'desegregates',
#  'latina women',
#  'environmentalsocial',
#  'environmental conscious',
#  'gender and sexual',
#  'inclusivity and diversity',
#  'lgbtqia',
#  'women and gender',
#  'genderdysphoria',
#  'misogynistic',
#  'multi ethnically',
#  'gender nonconforming',
#  'segregated race',
#  'environmental equity',
#  'sexual disparity',
#  'nonwhite',
#  'undervalued',
#  'hispanic cultures',
#  'white female',
#  'victimhood',
#  'systems of power',
#  'cultural advocate',
#  'climate research',
#  'latinamale',
#  'intersectional feminism',
#  'racial segregation',
#  'hispanic women',
#  'white people',
#  'latinxmales',
#  'racial socialization',
#  'statuses',
#  'ethnic culture',
#  'cultural inequity',
#  'climate conscious',
#  'equities',
#  'oppressiveness',
#  'gender minorities',
#  'social advocacy',
#  'gender preferences',
#  'climatejustices',
#  'oppressed genders',
#  'netzero',
#  'gender neural',
#  'hispanic community',
#  'gender oppression',
#  'environmentalgovernance',
#  'social inequity',
#  'ethnical racism',
#  'community inclusivity',
#  'sex transition',
#  'ethnic communities',
#  'environment conscious',
#  'cultural injustices',
#  'inter racially',
#  'socially relevant',
#  'systematic oppression',
#  'hispanic individuals',
#  'latina individuals',
#  'decolonize',
#  'black indigenous latinx',
#  'ethnic individual',
#  'cultural connections',
#  'transitioning sex',
#  'gender binary',
#  'sense of belongingness',
#  'transitioning gender',
#  'genderdiscrimination',
#  'latina female',
#  'climate justice',
#  'critical race theory',
#  'social inequities',
#  'fostering diversity',
#  'systemical',
#  'under appreciation',
#  'emphasize diversity',
#  'cultural and racial',
#  'culturalcompetency',
#  'diversity equity',
#  'culture and race',
#  'bias towards',
#  'hispanic culture',
#  'social activists',
#  'green society',
#  'female voices',
#  'foster diversity',
#  'colored female',
#  'unequal opportunities',
#  'deij',
#  'sexist',
#  'micro aggression',
#  'lgbtq+',
#  'systemic racism',
#  'ethnicminorities',
#  'sex change',
#  'feministic',
#  'tokensim',
#  'emphasizing diversity',
#  'diverse voices',
#  'indigenous people',
#  'anti racist',
#  'racial and ethnic',
#  'genderstereotypes',
#  'racial prejudices',
#  'bigotry',
#  'environmental consciousness',
#  'socially biased',
#  'gender disparity',
#  'bi cultural',
#  'ethnic identity',
#  'sexualminority',
#  'divisiveness',
#  'clean energy',
#  'privileges',
#  'systematically oppressed',
#  'social bias',
#  'latina males',
#  'white person',
#  'colored minorities',
#  'biases toward',
#  'latinx cultures',
#  'anti black',
#  'latinx cultural',
#  'racial inequalities',
#  'equalities',
#  'victimized',
#  'whitenationalism',
#  'ethnic people',
#  'culturalactivist',
#  'hispanic person',
#  'de colonizing',
#  'gender disparities',
#  'ethnic segregation',
#  'latinx culture',
#  'primarily male',
#  'social activist',
#  'white males',
#  'ethnic individuals',
#  'voices heard',
#  'straight white',
#  'systemically oppressed',
#  'racial biases',
#  'racial minorities']

# %%
list(flagged_new - senate_terms)
# Out:
# ['hesitancy',
#  'diverse communities',
#  'racial diversity',
#  'pollution',
#  'immigrants',
#  'cultural sensitivity',
#  'affirming care',
#  'deia',
#  'assigned at birth',
#  'race',
#  'assigned male at birth',
#  'hesitant',
#  'vulnerable populations',
#  'anti-racism',
#  'latinx',
#  'bias',
#  'health equity',
#  'diversity',
#  'msm',
#  'mx',
#  'cultural competence',
#  'vaccine',
#  'accessible',
#  'sense of belonging',
#  'vaccinate',
#  'belong',
#  'person-centered',
#  'climate science',
#  'native american',
#  'black',
#  'key populations',
#  'pregnant persons',
#  'sex',
#  'orientation',
#  'disparity',
#  'pregnant people',
#  'gender-affirming care',
#  'health disparity',
#  'at risk',
#  'diverse',
#  'vaccination',
#  'identity',
#  'pregnant person',
#  'vaccines',
#  'key groups',
#  'culturally appropriate',
#  'tribal',
#  'person-centered care',
#  'non-binary',
#  'most risk',
#  'race and ethnicity',
#  'mental health',
#  'men who have sex with men',
#  'mrna',
#  'expression',
#  'assigned female at birth',
#  'trans']

# %% [markdown]
# https://www.science.org/doi/abs/10.1126/science.1136800
# Affinity propagation for clustering words in list

# %% [markdown]
# find which senate-specified words are in abstracts

# %%
flagged = []

for i in df['abstract'].str.lower():
    curr = []
    if i != i:  #add nans
        continue
    for j in senate_terms:
        if j in i:
            curr.append(j)
    flagged.append(curr)

# %%
flagged
# Out:
# [[],
#  ['ally'],
#  ['biased'],
#  ['ally'],
#  ['ally'],
#  ['ally'],
#  ['barrier', 'ally'],
#  ['poc', 'ally'],
#  ['heterosexual', 'victim', 'discrimination', 'minority', 'victims', 'ally'],
#  ['women',
#   'heterosexual',
#   'gender',
#   'victim',
#   'minority',
#   'victims',
#   'historically',
#   'ally'],
#  ['women', 'exclusive', 'ally'],
#  ['ally'],
#  ['women'],
#  ['women', 'heterosexual', 'female', 'minority', 'ally'],
#  ['women'],
#  ['lgbtq',
#   'heterosexual',
#   'gender',
#   'female',
#   'gender identity',
#   'victim',
#   'lgbt',
#   'sexism',
#   'minority',
#   'ally',
#   'racial',
#   'sexist',
#   'lgbtq+'],
#  ['ally'],
#  ['ally'],
#  [],
#  ['sexual identity',
#   'ethnicity',
#   'minorities',
#   'marginalization',
#   'heterosexual',
#   'sexual minorities',
#   'equitable',
#   'intersectional',
#   'minority',
#   'ally',
#   'marginalized',
#   'status',
#   'marginalize'],
#  [],
#  ['ethnicity',
#   'gender minority',
#   'gender',
#   'equity',
#   'advocate',
#   'activists',
#   'activist',
#   'gender identity',
#   'intersectional',
#   'minority',
#   'ally',
#   'intersectionality'],
#  ['women', 'ally'],
#  ['ally'],
#  ['gender', 'ally'],
#  [],
#  ['women',
#   'heterosexual',
#   'gender',
#   'sociocultural',
#   'intersectional',
#   'minority',
#   'ally',
#   'racially',
#   'black women',
#   'sexuality',
#   'latina women',
#   'racial',
#   'underrepresentation',
#   'socioeconomic'],
#  ['trauma', 'ally'],
#  ['ally'],
#  ['ally', 'excluded'],
#  ['diverse background',
#   'gender',
#   'diverse group',
#   'diverse backgrounds',
#   'ally',
#   'racial',
#   'racial and ethnic',
#   'underrepresented',
#   'underserved'],
#  ['sexual identity',
#   'women',
#   'ethnicity',
#   'heterosexual',
#   'gender minority',
#   'gender',
#   'minority'],
#  ['institutional',
#   'ethnicity',
#   'heterosexual',
#   'culturally sensitive',
#   'racist',
#   'ethnic minority',
#   'discrimination',
#   'intersectional',
#   'sexism',
#   'minority',
#   'ally',
#   'marginalized',
#   'racism',
#   'oppression',
#   'racial',
#   'marginalize'],
#  ['equities', 'inequities'],
#  ['lgbtq',
#   'women',
#   'heterosexual',
#   'victim',
#   'lgbt',
#   'minority',
#   'ally',
#   'lgbtq+'],
#  ['ethnicity',
#   'heterosexual',
#   'cisgender',
#   'gender minority',
#   'gender',
#   'culturally relevant',
#   'gender identity',
#   'minority',
#   'ally',
#   'equities',
#   'inequities'],
#  ['institutional', 'inclusive', 'ally'],
#  ['sexual identity',
#   'ethnicity',
#   'minorities',
#   'heterosexual',
#   'sexual minorities',
#   'gender minority',
#   'gender',
#   'gender identity',
#   'discrimination',
#   'minority',
#   'ally'],
#  ['sexual identity',
#   'ethnicity',
#   'minorities',
#   'heterosexual',
#   'sexual minorities',
#   'gender minority',
#   'gender',
#   'gender identity',
#   'discrimination',
#   'minority',
#   'ally'],
#  ['transgender',
#   'ethnicity',
#   'cisgender',
#   'gender',
#   'microaggression',
#   'masculine',
#   'microaggressions',
#   'discrimination',
#   'intersectional',
#   'minority',
#   'ally',
#   'racially',
#   'oppression',
#   'status',
#   'racial',
#   'equities',
#   'inequities',
#   'systematic oppression',
#   'intersectionality'],
#  ['ally'],
#  ['ally'],
#  ['sexual identity',
#   'cisgender',
#   'gender',
#   'exclusive',
#   'female',
#   'gender identity',
#   'minority',
#   'ally',
#   'marginalized',
#   'sexuality',
#   'marginalize'],
#  ['women', 'ally'],
#  ['ally'],
#  ['lgbtq',
#   'transgender',
#   'minorities',
#   'heterosexual',
#   'cisgender',
#   'gender',
#   'discrimination',
#   'lgbt',
#   'minority',
#   'ally',
#   'transphobia',
#   'gender minorities',
#   'lgbtq+'],
#  ['ally'],
#  ['ally'],
#  ['lgbtq',
#   'gender minority',
#   'gender',
#   'lgbt',
#   'minority',
#   'transphobia',
#   'lgbtq+'],
#  ['equality', 'cisgender', 'gender minority', 'gender', 'minority', 'ally'],
#  ['lgbtq',
#   'gender minority',
#   'gender',
#   'victim',
#   'lgbt',
#   'minority',
#   'victims',
#   'ally',
#   'lgbtq+'],
#  ['ethnicity',
#   'barrier',
#   'barriers',
#   'ally',
#   'racially',
#   'racial',
#   'socioeconomic'],
#  ['ally'],
#  ['reparation'],
#  ['ally'],
#  ['women', 'heterosexual', 'minority', 'ally', 'stereotypes', 'stereotype'],
#  ['ally'],
#  ['female', 'females', 'victim', 'ally'],
#  ['barrier', 'barriers', 'ally'],
#  [],
#  ['women',
#   'diversity and inclusion',
#   'gender',
#   'female',
#   'females',
#   'inclusion',
#   'ally'],
#  ['ally'],
#  ['women', 'trauma', 'ally'],
#  ['ally'],
#  ['women',
#   'sexualities',
#   'heterosexual',
#   'gender',
#   'victim',
#   'inclusion',
#   'ally'],
#  ['barrier', 'ally'],
#  ['lgbtq',
#   'transgender',
#   'trauma',
#   'enhance diversity',
#   'culturally sensitive',
#   'cisgender',
#   'diversity and inclusion',
#   'gender',
#   'barrier',
#   'barriers',
#   'lgbt',
#   'inclusion',
#   'intersectional',
#   'ally',
#   'transphobia',
#   'lgbtq+'],
#  ['women',
#   'trauma',
#   'misogyny',
#   'heterosexual',
#   'traumatic',
#   'victim',
#   'minority',
#   'ally',
#   'sexist'],
#  ['minority'],
#  ['women',
#   'cisgender',
#   'gender minority',
#   'gender',
#   'discrimination',
#   'minority',
#   'ally'],
#  ['women'],
#  ['ally'],
#  ['poc'],
#  [],
#  ['minority', 'ally', 'racially', 'racial'],
#  ['historically', 'ally', 'underrepresented'],
#  ['ally'],
#  ['ally'],
#  ['institutional', 'ethnicity', 'ally', 'status', 'socioeconomic'],
#  [],
#  ['poc', 'ally'],
#  ['ally', 'systemic'],
#  ['ally'],
#  ['ally'],
#  ['ally'],
#  ['ally'],
#  ['ally'],
#  ['women', 'disabilities', 'ally', 'socioeconomic'],
#  ['advancing diversity',
#   'ethnic minority',
#   'disabilities',
#   'minority',
#   'diversify',
#   'ally',
#   'racial',
#   'racial and ethnic',
#   'underrepresented'],
#  ['biased', 'ally'],
#  ['ally', 'systemic'],
#  ['transgender',
#   'women',
#   'minorities',
#   'gender',
#   'gender affirming',
#   'gender minorities'],
#  ['status'],
#  ['ally'],
#  ['women', 'minorities', 'disabilities', 'ally'],
#  ['ally', 'status'],
#  ['institutional',
#   'advancing diversity',
#   'enhancing diversity',
#   'minority',
#   'diversify',
#   'ally',
#   'underrepresented'],
#  ['ally', 'status'],
#  ['barrier', 'ally'],
#  ['poc', 'ally'],
#  ['women', 'female', 'females', 'status'],
#  ['institutional',
#   'advancing diversity',
#   'ethnic minority',
#   'minority',
#   'historically',
#   'ally'],
#  ['institutional', 'ally'],
#  ['privileged', 'ally', 'privilege'],
#  [],
#  ['poc', 'ally'],
#  ['ethnicity',
#   'poc',
#   'black and latinx',
#   'ally',
#   'status',
#   'racial',
#   'racial and ethnic',
#   'socioeconomic'],
#  ['gender', 'minority', 'ally', 'underrepresented'],
#  ['ally', 'racially', 'racial'],
#  [],
#  ['ally', 'disability'],
#  ['ally', 'status', 'socioeconomic'],
#  ['multiethnic', 'ally'],
#  ['sociocultural',
#   'minority',
#   'historically',
#   'ally',
#   'inequalities',
#   'excluded',
#   'equalities'],
#  ['institutional', 'social environmental', 'ally'],
#  ['ally'],
#  ['women',
#   'gender',
#   'equity',
#   'sociocultural',
#   'minority',
#   'ally',
#   'women and gender',
#   'underrepresented'],
#  ['ally'],
#  ['women', 'minorities', 'sexual minorities', 'gender', 'diversified'],
#  [],
#  [],
#  ['ally'],
#  ['ally'],
#  ['ethnicity'],
#  ['biased', 'ally', 'underserved'],
#  ['poc', 'exclusion'],
#  ['minorities',
#   'ally',
#   'racially',
#   'racial',
#   'socioeconomic',
#   'racial minorities'],
#  [],
#  ['lgbtq',
#   'gender minority',
#   'gender',
#   'inclusive',
#   'gender identity',
#   'lgbt',
#   'minority',
#   'ally',
#   'lgbtq+',
#   'underrepresented'],
#  ['lgbtq',
#   'transgender',
#   'minorities',
#   'cisgender',
#   'diversity and inclusion',
#   'gender minority',
#   'gender',
#   'equity',
#   'inclusive',
#   'lgbt',
#   'inclusion',
#   'minority',
#   'ally',
#   'status',
#   'gender and sexual',
#   'gender minorities',
#   'dei'],
#  ['biased', 'ally'],
#  ['ethnicity',
#   'minorities',
#   'gender',
#   'lack of diversity',
#   'female',
#   'ally',
#   'racial',
#   'racial and ethnic'],
#  ['poc'],
#  [],
#  ['inclusion', 'ally', 'status'],
#  ['ally', 'biases'],
#  ['ally'],
#  ['ally'],
#  ['ethnicity', 'minorities', 'ally', 'racial'],
#  ['ally'],
#  ['ally'],
#  ['ally', 'status'],
#  ['ethnic and racial', 'ally', 'racial'],
#  ['advancing diversity',
#   'diverse background',
#   'diverse backgrounds',
#   'historically',
#   'ally',
#   'underrepresented'],
#  ['ally', 'racial', 'socioeconomic', 'underrepresented'],
#  ['ally', 'diversified'],
#  [],
#  ['ally', 'systemic'],
#  ['biased'],
#  ['ally'],
#  ['ally'],
#  ['sociocultural',
#   'bicultural',
#   'latinx communities',
#   'status',
#   'socioeconomic'],
#  ['ally'],
#  [],
#  ['ally'],
#  ['ethnic minority', 'minority', 'ally', 'racial'],
#  ['biased', 'ally'],
#  ['ally'],
#  ['advancing diversity',
#   'minority',
#   'historically',
#   'ally',
#   'underrepresented'],
#  ['trauma', 'poc', 'traumatic', 'ally'],
#  ['ally'],
#  ['institutional'],
#  ['poc', 'ally'],
#  ['poc',
#   'equity',
#   'barrier',
#   'barriers',
#   'ally',
#   'status',
#   'disability',
#   'socioeconomic'],
#  ['advocate', 'advocates', 'ally'],
#  ['poc', 'ally'],
#  ['ally'],
#  [],
#  ['ally'],
#  ['biased', 'ally', 'systemic'],
#  ['poc', 'ally'],
#  ['ally', 'status', 'socioeconomic'],
#  ['biased'],
#  ['ally'],
#  ['women',
#   'social environmental',
#   'racial disparities',
#   'ally',
#   'black women',
#   'racial',
#   'underrepresented'],
#  ['minorities',
#   'heterosexual',
#   'cisgender',
#   'gender',
#   'barrier',
#   'barriers',
#   'minority',
#   'marginalized',
#   'marginalize'],
#  ['poc', 'ally'],
#  ['ally', 'socioeconomic'],
#  ['ally'],
#  ['minorities',
#   'barrier',
#   'barriers',
#   'minority',
#   'racial',
#   'racial and ethnic',
#   'socioeconomic',
#   'underserved'],
#  ['diverse background', 'diverse backgrounds', 'ally', 'disability'],
#  ['ally', 'status', 'racial'],
#  ['barrier', 'barriers', 'pronoun'],
#  ['ally'],
#  ['ally'],
#  ['minorities',
#   'reparation',
#   'female',
#   'ethnic and racial',
#   'minority',
#   'racial',
#   'underrepresentation',
#   'underrepresented',
#   'racial minorities'],
#  ['institutional',
#   'lack of diversity',
#   'advocate',
#   'diverse group',
#   'advocates',
#   'historically',
#   'ally',
#   'status',
#   'equities',
#   'inequities',
#   'underrepresented'],
#  ['women',
#   'minorities',
#   'enhance the diversity',
#   'equity',
#   'women and underrepresented',
#   'ally',
#   'racial',
#   'racial and ethnic',
#   'political',
#   'underrepresented'],
#  ['ally'],
#  ['women'],
#  ['barrier', 'barriers', 'ally'],
#  ['ally'],
#  ['ally', 'biases'],
#  ['transgender', 'gender', 'lgbt', 'disabilities'],
#  ['ally'],
#  ['female', 'ally'],
#  ['barrier', 'barriers', 'ally'],
#  ['ally'],
#  ['barrier', 'ally', 'socioeconomic'],
#  ['lack of diversity', 'status'],
#  ['institutional',
#   'diversifying',
#   'minority',
#   'historically',
#   'diversify',
#   'ally',
#   'increasing diversity',
#   'socioeconomic',
#   'underrepresented',
#   'underserved'],
#  ['ally'],
#  ['ally'],
#  [],
#  ['biased',
#   'ethnic and racial',
#   'racial disparities',
#   'minority',
#   'ally',
#   'racial'],
#  ['ally'],
#  [],
#  ['biased', 'minority', 'ally'],
#  ['ally'],
#  ['ally', 'systemic', 'status'],
#  [],
#  [],
#  ['ally'],
#  ['ally'],
#  ['ally'],
#  ['barrier', 'systemically', 'ally', 'systemic', 'systemical'],
#  [],
#  ['female', 'females', 'pronoun'],
#  ['ally'],
#  ['diverse group', 'minority', 'ally'],
#  ['women', 'racial disparity', 'minority', 'ally', 'racial'],
#  ['ally', 'biases'],
#  ['institutional', 'ally'],
#  ['women',
#   'black individuals',
#   'racial disparities',
#   'black individual',
#   'ally',
#   'racial',
#   'biases'],
#  ['women',
#   'black individuals',
#   'racial disparities',
#   'black individual',
#   'ally',
#   'racial',
#   'biases'],
#  ['ally', 'systemic'],
#  ['inclusion', 'minority', 'ally', 'underrepresented'],
#  ['ally', 'underserved'],
#  [],
#  [],
#  ['barrier', 'barriers', 'minority', 'ally'],
#  ['ally'],
#  ['ally'],
#  ['poc'],
#  ['ally'],
#  ['gender affirmation',
#   'transgender',
#   'cisgender',
#   'gender minority',
#   'gender',
#   'barrier',
#   'barriers',
#   'gender identity',
#   'minority',
#   'ally'],
#  ['ally'],
#  ['ally'],
#  ['ally'],
#  ['ally'],
#  ['ally'],
#  ['ally'],
#  ['ally'],
#  ['women', 'ally'],
#  ['institutional',
#   'women',
#   'poc',
#   'segregation',
#   'structural racism',
#   'discrimination',
#   'ally',
#   'black women',
#   'racism',
#   'status',
#   'racial',
#   'equities',
#   'inequities',
#   'socioeconomic'],
#  ['institutional',
#   'women',
#   'poc',
#   'segregation',
#   'structural racism',
#   'discrimination',
#   'ally',
#   'black women',
#   'racism',
#   'status',
#   'racial',
#   'equities',
#   'inequities',
#   'socioeconomic'],
#  ['poc',
#   'racial identity',
#   'discrimination',
#   'black communities',
#   'ally',
#   'racism',
#   'racial'],
#  ['reparation', 'ally'],
#  ['trauma', 'traumatic'],
#  ['ethnicity'],
#  [],
#  ['minorities', 'minority', 'ally', 'racial', 'racial and ethnic'],
#  ['ally'],
#  ['ally'],
#  ['poc', 'reparation'],
#  ['ally', 'diverse individual'],
#  [],
#  ['ethnicity', 'gender', 'ally', 'status', 'socioeconomic'],
#  [],
#  [],
#  ['systemic'],
#  ['ally'],
#  ['ally', 'socioeconomic'],
#  ['reparation', 'ally'],
#  ['reparation'],
#  ['gender', 'status', 'racial', 'socioeconomic', 'gender disparities'],
#  ['ally'],
#  [],
#  ['biased', 'poc', 'inclusion', 'ally'],
#  ['systemically', 'ally', 'systemic', 'disability', 'systemical'],
#  ['ally'],
#  ['poc', 'barrier', 'barriers', 'ally'],
#  ['status'],
#  ['poc', 'ally', 'status'],
#  ['poc', 'ally', 'status'],
#  ['biased'],
#  ['minority', 'ally', 'systemic'],
#  ['poc', 'privileged', 'ally', 'privilege'],
#  ['ally', 'racial', 'racial and ethnic'],
#  ['women', 'gender', 'ally'],
#  ['polarization', 'disability'],
#  ['polarization', 'disability'],
#  ['ally'],
#  ['ally'],
#  ['reparation', 'ally'],
#  ['ally'],
#  ['ally', 'status'],
#  ['women', 'female', 'females', 'ally', 'status'],
#  ['ethnicity', 'ally', 'socioeconomic'],
#  ['advancing diversity',
#   'lack of diversity',
#   'increase diversity',
#   'diverse group',
#   'diverse groups',
#   'ally',
#   'underrepresented'],
#  ['lgbtq',
#   'women',
#   'minorities',
#   'diverse background',
#   'increase diversity',
#   'lgbt',
#   'diverse backgrounds',
#   'disabilities',
#   'ally',
#   'lgbtq+',
#   'underrepresented'],
#  ['institutional',
#   'enhance diversity',
#   'barrier',
#   'advance diversity',
#   'minority',
#   'increase the diversity',
#   'ally',
#   'equities',
#   'inequities',
#   'underrepresented'],
#  ['minorities',
#   'barrier',
#   'ethnic minority',
#   'advocate',
#   'barriers',
#   'minority',
#   'ally',
#   'systemic',
#   'racial',
#   'underrepresented'],
#  ['promote diversity',
#   'enhance diversity',
#   'minorities',
#   'diverse background',
#   'barrier',
#   'ethnic minority',
#   'barriers',
#   'diverse group',
#   'diverse backgrounds',
#   'minority',
#   'ally',
#   'racial',
#   'racial and ethnic',
#   'underrepresented'],
#  ['poc',
#   'equity',
#   'people of color',
#   'diversifying',
#   'bipoc',
#   'diversify',
#   'ally',
#   'racially',
#   'racial',
#   'underrepresented'],
#  ['women',
#   'ethnicity',
#   'inclusive',
#   'increase diversity',
#   'disabilities',
#   'minority',
#   'ally',
#   'racially',
#   'racial',
#   'disability',
#   'racial and ethnic',
#   'underrepresented'],
#  ['institutional', 'poc'],
#  ['barrier', 'barriers', 'ally', 'diversified'],
#  ['barrier', 'barriers', 'ally'],
#  ['equity',
#   'minority',
#   'ally',
#   'racially',
#   'racial',
#   'disability',
#   'underrepresented'],
#  ['female', 'ally'],
#  ['barrier', 'barriers', 'ally'],
#  ['ally'],
#  ['ally'],
#  ['ally'],
#  ['poc'],
#  ['poc', 'ally'],
#  ['diverse background',
#   'latinx individuals',
#   'barrier',
#   'barriers',
#   'diverse backgrounds',
#   'ally',
#   'latinx individual',
#   'socioeconomic',
#   'underserved'],
#  ['ally', 'systemic'],
#  ['racial disparity', 'ally', 'racial'],
#  ['ally'],
#  ['ally'],
#  ['ally', 'disability'],
#  ['ally'],
#  ['barrier'],
#  ['ally'],
#  ['ally'],
#  ['ally', 'status'],
#  ['transgender',
#   'women',
#   'minorities',
#   'heterosexual',
#   'gender',
#   'structural racism',
#   'discrimination',
#   'minority',
#   'racism',
#   'status',
#   'racial',
#   'gender minorities'],
#  ['trauma', 'traumatic'],
#  ['ally'],
#  ['socioeconomic'],
#  ['ally', 'status'],
#  ['ally', 'disability'],
#  ['exclusive', 'ally'],
#  ['ally'],
#  ['barrier', 'ally'],
#  ['biased', 'inclusion', 'ally'],
#  ['women', 'ally'],
#  [],
#  ['equitable',
#   'equity',
#   'barrier',
#   'inequity',
#   'barriers',
#   'racial disparities',
#   'ally',
#   'racial',
#   'biases'],
#  [],
#  ['female', 'ally'],
#  [],
#  ['ally'],
#  ['ally', 'systemic'],
#  ['ally', 'systemic'],
#  ['women', 'ally'],
#  ['ally'],
#  ['ally'],
#  ['ally', 'underrepresented'],
#  ['poc', 'ally', 'disability'],
#  ['poc', 'ally', 'disability'],
#  ['poc', 'ally', 'disability'],
#  ['ally'],
#  ['ally', 'socioeconomic', 'underrepresented'],
#  ['barrier', 'status'],
#  ['women', 'poc', 'female', 'females', 'ally'],
#  ['segregation',
#   'discrimination',
#   'minority',
#   'racism',
#   'status',
#   'stereotypes',
#   'stereotype',
#   'socioeconomic'],
#  ['ally'],
#  ['barrier', 'ally'],
#  ['systemic'],
#  ['ally'],
#  ['ally'],
#  ['ally'],
#  ['ally'],
#  ['ally', 'status'],
#  ['ally'],
#  ['ally'],
#  ['lack of diversity',
#   'historically',
#   'ally',
#   'racially',
#   'racial',
#   'racial and ethnic',
#   'underserved'],
#  ['ally', 'status'],
#  ['ally'],
#  ['ally'],
#  ['ally'],
#  ['poc', 'barrier', 'ally'],
#  ['equality',
#   'equity',
#   'structural racism',
#   'racial disparities',
#   'racial inequality',
#   'inequality',
#   'inequalities',
#   'racism',
#   'racial',
#   'disability',
#   'equalities',
#   'social justice'],
#  ['ally'],
#  ['ally'],
#  ['ally'],
#  ['sociocultural', 'ally'],
#  ['sociocultural', 'ally'],
#  ['barrier', 'barriers'],
#  [],
#  ['poc', 'discrimination', 'ally'],
#  ['trauma', 'traumatic', 'ally'],
#  ['trauma',
#   'traumatic',
#   'racial disparities',
#   'discrimination',
#   'ally',
#   'racial',
#   'equities',
#   'inequities',
#   'social inequities'],
#  ['lgbtq',
#   'gender minority',
#   'gender',
#   'gender identity',
#   'discrimination',
#   'lgbt',
#   'minority',
#   'status',
#   'statuses',
#   'lgbtq+'],
#  ['lgbtq',
#   'gender minority',
#   'gender',
#   'gender identity',
#   'discrimination',
#   'lgbt',
#   'minority',
#   'status',
#   'statuses',
#   'lgbtq+'],
#  ['poc'],
#  ['status'],
#  ['ally'],
#  ['ally'],
#  ['institutional',
#   'equitable',
#   'lack of diversity',
#   'reparation',
#   'equity',
#   'barrier',
#   'exclusion',
#   'inclusive',
#   'barriers',
#   'historically',
#   'diversify',
#   'ally',
#   'underrepresentation',
#   'excluded',
#   'underrepresented'],
#  ['equity',
#   'sociocultural',
#   'increase diversity',
#   'historically',
#   'ally',
#   'racially',
#   'racial'],
#  ['ethnic minority',
#   'minority',
#   'ally',
#   'racially',
#   'racial',
#   'racial and ethnic',
#   'underrepresented'],
#  ['racial disparity',
#   'racial disparities',
#   'black communities',
#   'ally',
#   'racial'],
#  ['women', 'people of color', 'ally', 'underserved'],
#  ['women', 'ally'],
#  ['disability'],
#  ['structural racism',
#   'racial disparities',
#   'black and latinx',
#   'historically',
#   'ally',
#   'marginalized',
#   'racism',
#   'racial',
#   'marginalize',
#   'political'],
#  ['ally'],
#  ['ally'],
#  [],
#  ['exclusive', 'ally', 'systemic'],
#  ['disability'],
#  ['ally'],
#  ['historically', 'ally'],
#  ['ally', 'underrepresented'],
#  ['minorities',
#   'reparation',
#   'equity',
#   'barrier',
#   'ethnic minority',
#   'barriers',
#   'minority',
#   'historically',
#   'ally',
#   'status',
#   'racial',
#   'equities',
#   'inequities',
#   'excluded',
#   'racial and ethnic'],
#  ['ally'],
#  ['poc'],
#  ['ally'],
#  ['ally'],
#  ['minority', 'ally'],
#  ['ally'],
#  ['minorities', 'ally', 'racial', 'underrepresented'],
#  ['institutional', 'barrier', 'barriers', 'ally'],
#  ['ally'],
#  ['disability'],
#  ['poc', 'ally'],
#  ['ally'],
#  ['racial disparities',
#   'discrimination',
#   'ally',
#   'inequalities',
#   'racially',
#   'racial',
#   'racial inequalities',
#   'equalities'],
#  [],
#  ['ally', 'biases'],
#  ['ally'],
#  ['ally'],
#  ['biased'],
#  ['ally'],
#  ['ally'],
#  ['inclusion'],
#  [],
#  ['lgbtq', 'lgbt', 'ally', 'racially', 'racial'],
#  ['ally'],
#  ['ally'],
#  ['minorities',
#   'heterosexual',
#   'sexual minorities',
#   'ally',
#   'disability',
#   'underrepresented'],
#  ['barrier', 'barriers'],
#  ['institutional', 'ally'],
#  ['diverse background',
#   'diverse backgrounds',
#   'minority',
#   'historically',
#   'diversify',
#   'ally',
#   'racially',
#   'racial',
#   'dei',
#   'socioeconomic'],
#  ['women', 'female', 'females', 'ally', 'status'],
#  [],
#  [],
#  ['gender minority',
#   'gender',
#   'barrier',
#   'barriers',
#   'discrimination',
#   'minority',
#   'ally',
#   'status',
#   'equities',
#   'inequities'],
#  ['barrier', 'barriers', 'ally', 'political'],
#  ['ally'],
#  ['female', 'ally', 'racially', 'racial'],
#  ['disability', 'advocacy'],
#  [],
#  ['ally'],
#  ['poc', 'female', 'ally'],
#  ['women', 'gender', 'inclusion', 'ally', 'underrepresented'],
#  ['ally'],
#  [],
#  [],
#  ['ally'],
#  ['ally'],
#  ['poc'],
#  ['barrier', 'barriers', 'ally'],
#  ['women', 'status', 'biases', 'socioeconomic'],
#  ['poc', 'ally'],
#  ['ally'],
#  ['women', 'minorities', 'political'],
#  [],
#  ['women', 'ally', 'black women'],
#  ['ally'],
#  ['ally'],
#  ['inclusion', 'ally', 'systemic'],
#  ['women', 'ally'],
#  ['barrier'],
#  ['ally', 'status', 'racial', 'socioeconomic'],
#  ['minorities',
#   'barrier',
#   'advocate',
#   'barriers',
#   'advocates',
#   'racial',
#   'racial and ethnic'],
#  ['ally'],
#  ['segregation',
#   'equitable',
#   'structural racism',
#   'ally',
#   'racism',
#   'racial',
#   'equities',
#   'inequities'],
#  ['underrepresented'],
#  ['ally'],
#  ['poc', 'ally'],
#  ['biased', 'ally'],
#  ['poc', 'ally'],
#  ['women', 'gender'],
#  ['advancing diversity',
#   'diverse background',
#   'diverse backgrounds',
#   'ally',
#   'status'],
#  ['diverse background',
#   'equity',
#   'diverse backgrounds',
#   'minority',
#   'underserved'],
#  ['ethnicity', 'culturally attuned', 'minority', 'ally', 'systemic'],
#  ['ally'],
#  ['gender'],
#  ['ally', 'systemic'],
#  ['ally'],
#  ['exclusion', 'ally'],
#  [],
#  ['ally'],
#  ['women', 'ally', 'status', 'biases', 'socioeconomic'],
#  ['racial inequities',
#   'racial prejudice',
#   'equity',
#   'structural racism',
#   'racial disparities',
#   'stereotyping',
#   'ally',
#   'racism',
#   'racial',
#   'equities',
#   'inequities',
#   'prejudice'],
#  ['ally', 'disability'],
#  ['women', 'exclusive', 'ally'],
#  ['systemic'],
#  [],
#  ['trauma',
#   'equality',
#   'segregation',
#   'gender',
#   'ethnic minority',
#   'female',
#   'discrimination',
#   'minority',
#   'inequality',
#   'ally',
#   'status',
#   'racial',
#   'ethnic identity',
#   'socioeconomic'],
#  [],
#  ['ally'],
#  ['ally', 'disability'],
#  ['poc', 'ally'],
#  ['equitable', 'ally'],
#  ['ally'],
#  ['ally', 'status'],
#  ['ally'],
#  ['ally'],
#  ['ally', 'stereotype'],
#  ['ally'],
#  ['lgbtq',
#   'heterosexual',
#   'barrier',
#   'barriers',
#   'discrimination',
#   'lgbt',
#   'ally',
#   'lgbtq+'],
#  ['women', 'gender', 'sociocultural', 'ally', 'racially', 'racial'],
#  ['ally'],
#  ['ally'],
#  ['barrier', 'ally'],
#  ['ally'],
#  ['ally', 'disability'],
#  ['ally', 'status'],
#  ['ally', 'status'],
#  ['diversity and inclusion', 'inclusion', 'ally', 'fostering diversity'],
#  ['equity', 'historically', 'ally', 'marginalized', 'marginalize'],
#  ['ally'],
#  ['ethnicity', 'ally'],
#  ['ally', 'status', 'socioeconomic'],
#  ['institutional', 'barrier', 'barriers', 'ally', 'socioeconomic'],
#  [],
#  ['intersectional', 'minority', 'ally'],
#  ['barrier', 'ally', 'socioeconomic'],
#  ['ally'],
#  ['ally'],
#  ['status', 'socioeconomic'],
#  ['ally'],
#  ['institutional'],
#  ['ally'],
#  ['women', 'inclusivity', 'minority', 'underrepresented'],
#  ['biased',
#   'social inequalities',
#   'barrier',
#   'ally',
#   'inequalities',
#   'status',
#   'socioeconomic',
#   'equalities'],
#  ['inclusion'],
#  ['reparation', 'reparations', 'ally'],
#  ['ally'],
#  ['intersectional', 'ally'],
#  ['ally', 'disability'],
#  [],
#  ['ally'],
#  ['poc', 'barrier'],
#  ['ally'],
#  ['ally'],
#  ['poc', 'barrier', 'barriers', 'ally'],
#  ['equity',
#   'structural racism',
#   'ally',
#   'marginalized',
#   'racism',
#   'status',
#   'racial',
#   'marginalize',
#   'socioeconomic'],
#  ['poc'],
#  [],
#  ['ally'],
#  ['segregation', 'ally'],
#  ['ally'],
#  ['ally'],
#  [],
#  ['institutional', 'minorities', 'underrepresented'],
#  ['disability'],
#  [],
#  ['ally'],
#  [],
#  [],
#  ['ally'],
#  ['ally'],
#  ['advocate', 'ally'],
#  ['ally'],
#  ['ally'],
#  ['ally'],
#  ['ally'],
#  ['ally'],
#  ['ally'],
#  ['ally'],
#  ['barrier', 'barriers'],
#  ['institutional',
#   'women',
#   'promote diversity',
#   'equity',
#   'inclusive',
#   'inclusion',
#   'dei'],
#  ['ally'],
#  ['ally'],
#  ['women', 'ally'],
#  ['ally'],
#  ['ally', 'status', 'underrepresented'],
#  ['transgender', 'women', 'gender', 'barrier', 'female', 'ally', 'systemic'],
#  ['ally'],
#  ['ally'],
#  ['women'],
#  ['transgender', 'women', 'gender', 'female', 'ally', 'excluded'],
#  [],
#  ['ally'],
#  [],
#  ['ally'],
#  ['biased', 'barrier', 'barriers', 'ally'],
#  ['ally', 'systemic'],
#  ['barrier', 'ally'],
#  ['ally'],
#  ['institutional'],
#  ['barrier'],
#  ['ally'],
#  ['biased', 'ally'],
#  ['discrimination', 'ally'],
#  ['ally'],
#  ['ally'],
#  ['historically', 'ally'],
#  ['biased', 'systemic'],
#  [],
#  ['female', 'females', 'ally'],
#  ['ally', 'status'],
#  ['ally'],
#  ['ally'],
#  ['institutional'],
#  [],
#  ['ally'],
#  ['institutional', 'minorities', 'reparation', 'underrepresented'],
#  ['ally'],
#  ['ally'],
#  ['ally'],
#  ['ally'],
#  [],
#  [],
#  ['reparation'],
#  [],
#  ['institutional', 'ally'],
#  [],
#  ['ally'],
#  ['ally'],
#  ['ally'],
#  ['ally'],
#  ['ally'],
#  ['women'],
#  [],
#  ['ally'],
#  ['ally'],
#  [],
#  ['ally'],
#  ['ally'],
#  ['ally'],
#  ['ally'],
#  ['barrier', 'ally', 'systemic'],
#  ['ally'],
#  ['ally', 'status'],
#  ['ally'],
#  ['ally'],
#  ['ally'],
#  [],
#  ['ally'],
#  ['equity', 'ally'],
#  ['exclusive', 'ally', 'status'],
#  ['ally'],
#  ['ally'],
#  ['barrier', 'barriers', 'ally'],
#  ['women',
#   'inclusiveness',
#   'inclusive',
#   'increase diversity',
#   'minority',
#   'increase the diversity',
#   'underrepresented'],
#  ['reparation', 'ally'],
#  ['ally'],
#  ['polarize', 'ally'],
#  ['ally', 'systemic'],
#  ['exclusive'],
#  [],
#  ['ally'],
#  ['ally'],
#  ['gender transition',
#   'transgender',
#   'women',
#   'cisgender',
#   'gender',
#   'barrier',
#   'barriers',
#   'discrimination',
#   'gender affirming',
#   'ally'],
#  ['women', 'barrier', 'ally'],
#  ['historically', 'ally', 'underrepresented'],
#  [],
#  ['ally'],
#  ['women', 'barrier', 'female', 'barriers', 'ally'],
#  ['historically', 'ally', 'biases'],
#  ['ally'],
#  ['ally'],
#  ['ally', 'systemic'],
#  ['barrier'],
#  ['barrier'],
#  ['ally'],
#  [],
#  [],
#  ['ally'],
#  ['barrier', 'ally'],
#  ['trauma', 'poc'],
#  ['ally', 'racially', 'racial'],
#  ['ally'],
#  ['ally'],
#  ['ally'],
#  ['ally'],
#  ['ally'],
#  ['female', 'females', 'ally'],
#  ['barrier'],
#  ['ally'],
#  ['ally'],
#  ['ally', 'systemic'],
#  ['ally'],
#  ['ally', 'status'],
#  ['ally'],
#  [],
#  ['ally'],
#  ['ally'],
#  ['ally'],
#  ['ally'],
#  ['ally'],
#  [],
#  [],
#  ['ally'],
#  [],
#  ['ally'],
#  ['ally'],
#  ['ally'],
#  [],
#  ['ally'],
#  [],
#  ['ally', 'marginalized', 'marginalize'],
#  ['ally'],
#  ['climate change'],
#  ['biased', 'historically', 'ally'],
#  [],
#  [],
#  ['ally'],
#  ['female', 'females', 'ally', 'status'],
#  ['ally'],
#  [],
#  [],
#  ['polarization', 'ally'],
#  ['barrier', 'ally'],
#  ['ally'],
#  ['female', 'females', 'ally'],
#  ['ally'],
#  [],
#  ['female', 'ally'],
#  ['barrier', 'ally'],
#  ['ally'],
#  [],
#  [],
#  ['transgender',
#   'women',
#   'trauma',
#   'gender',
#   'female',
#   'gender identity',
#   'minority',
#   'ally',
#   'status'],
#  ['minority', 'historically', 'ally'],
#  ['women', 'ally'],
#  ['ally'],
#  ['ally'],
#  [],
#  ['ally'],
#  [],
#  ['barrier', 'ally', 'systemic'],
#  ['ally'],
#  ['diversifying', 'diversify', 'ally'],
#  [],
#  ['ally', 'systemic', 'excluded'],
#  ['barrier', 'ally'],
#  [],
#  ['barrier', 'barriers', 'ally', 'excluded'],
#  [],
#  ['ally'],
#  ['gender', 'ally'],
#  ['ally'],
#  ['ally'],
#  ['ally'],
#  ['ally'],
#  [],
#  ['systemic'],
#  ['ally'],
#  [],
#  ['ally', 'systemic'],
#  [],
#  [],
#  ['ethnicity', 'ally', 'racial', 'racial and ethnic'],
#  ['systemic', 'status'],
#  ['barrier', 'ally'],
#  ['ally'],
#  [],
#  ['ally'],
#  ['ally'],
#  ['ally'],
#  [],
#  ['institutional', 'ally'],
#  ['ally'],
#  ['barrier', 'ally'],
#  ['ally'],
#  ['poc'],
#  ['ally'],
#  ['barrier', 'barriers', 'ally', 'systemic'],
#  [],
#  ['ally'],
#  ['ally'],
#  ['ally'],
#  ['barrier', 'ally'],
#  ['ally', 'status'],
#  ['systemic'],
#  ['barrier', 'culturally relevant', 'barriers', 'ally'],
#  ['ally'],
#  ['ally'],
#  ['ally'],
#  ['ally'],
#  ['ally'],
#  ['exclusive', 'ally'],
#  ['exclusive', 'ally'],
#  ['ally'],
#  [],
#  ['female', 'ally'],
#  ['ally'],
#  ['equity', 'barrier', 'barriers', 'ally', 'socioeconomic'],
#  ['ally'],
#  ['segregation'],
#  ['equity',
#   'barrier',
#   'barriers',
#   'minority',
#   'ally',
#   'advocacy',
#   'underserved'],
#  [],
#  ['reparation'],
#  ['ally'],
#  ['ally'],
#  ['ally'],
#  ['ally'],
#  ['barrier', 'barriers', 'inclusion', 'intersectional', 'ally'],
#  ['inclusion', 'ally', 'dei'],
#  ['ally'],
#  ['ally'],
#  ['ally'],
#  ['barrier'],
#  ['barrier', 'ally'],
#  ['ally'],
#  ['exclusive', 'ally'],
#  ['ally'],
#  [],
#  ['ally'],
#  [],
#  ['ally', 'systemic'],
#  ['ally'],
#  ['ally'],
#  ['ally'],
#  ['women', 'excluded'],
#  ['institutional', 'ally'],
#  [],
#  ['ally'],
#  ['barrier', 'barriers', 'ally'],
#  ['barrier',
#   'barriers',
#   'black and latinx',
#   'latinx communities',
#   'ally',
#   'racial',
#   'equities',
#   'inequities',
#   'socioeconomic'],
#  ['barrier', 'barriers'],
#  ['ally', 'socioeconomic'],
#  ['inclusive'],
#  ['ally'],
#  ['barrier', 'barriers', 'ally'],
#  ['institutional',
#   'reparation',
#   'equity',
#   'diverse group',
#   'inclusion',
#   'increase the diversity',
#   'ally',
#   'underrepresented'],
#  ['polarize', 'ally'],
#  ['ally'],
#  ['barrier', 'systemically', 'ally', 'systemic', 'systemical'],
#  ['ally'],
#  ['biased', 'barrier'],
#  ['systemic'],
#  ['ally'],
#  ['ally'],
#  ['ally', 'systemic'],
#  ['barrier', 'advocate', 'barriers', 'advocates', 'ally'],
#  ['diversify', 'ally'],
#  [],
#  ['ally'],
#  ['ally'],
#  ['ally'],
#  ['ally'],
#  ['ally'],
#  ['biased', 'ally'],
#  ['ally'],
#  ['ally', 'systemic'],
#  ['ally'],
#  ['ally'],
#  ['ally'],
#  ['women', 'gender', 'female', 'females', 'ally'],
#  ['ally'],
#  ['women'],
#  [],
#  ['ally', 'systemic'],
#  ['systemic'],
#  ['ally'],
#  ['ally'],
#  ['biased', 'climate change', 'ally'],
#  ['barrier', 'ally'],
#  ['ally'],
#  [],
#  ['women', 'ally'],
#  ['ally'],
#  ['ally'],
#  ['minorities',
#   'diverse background',
#   'ethnic minority',
#   'diverse backgrounds',
#   'minority',
#   'increase the diversity',
#   'historically',
#   'ally',
#   'racial',
#   'racial and ethnic'],
#  ['ally'],
#  ['ally'],
#  ['barrier', 'ally', 'systemic'],
#  [],
#  ['ally'],
#  ['ally'],
#  ['women', 'ally'],
#  ['ally'],
#  ['polarize', 'polarization'],
#  ['ally'],
#  ['ally'],
#  ['ally'],
#  ['ally'],
#  ['ally'],
#  ['ally'],
#  ['ally'],
#  [],
#  ['barrier', 'barriers', 'ally'],
#  [],
#  ['ally'],
#  ['systemic'],
#  ['ally'],
#  ['ally'],
#  ['biased', 'female', 'females', 'ally'],
#  ['biased', 'female', 'females', 'ally'],
#  ['underappreciated'],
#  ['polarization', 'ally'],
#  ['intersectional', 'ally'],
#  ['ally'],
#  ['transgender',
#   'women',
#   'cisgender',
#   'equitable',
#   'gender',
#   'barrier',
#   'barriers',
#   'historically',
#   'ally',
#   'racially',
#   'black women',
#   'racial',
#   'equities',
#   'inequities',
#   'racial and ethnic',
#   'underrepresented',
#   'underserved'],
#  ['barrier', 'barriers', 'ally'],
#  ['ally'],
#  ['equity',
#   'ethnic and racial',
#   'historically',
#   'ally',
#   'racial',
#   'underrepresented'],
#  ['ally'],
#  ['ally'],
#  ['ally'],
#  ['ally', 'systemic'],
#  ['ally'],
#  ['status'],
#  ['reparation', 'reparations'],
#  ['barrier', 'ally'],
#  ['exclusive', 'ally'],
#  ['ally', 'systemic'],
#  [],
#  ['ally'],
#  ['ally', 'systemic'],
#  ['barrier', 'ally'],
#  ['ally'],
#  ['ethnicity', 'ally', 'status', 'racial', 'political', 'socioeconomic'],
#  ['ally'],
#  ['ally'],
#  ['ally'],
#  ['ally'],
#  ['ally'],
#  ['ally'],
#  ['minority'],
#  ['ally'],
#  ['barrier', 'barriers', 'ally'],
#  ['ally'],
#  ['ally'],
#  ['ally'],
#  ['ally'],
#  ['ally'],
#  ['female', 'females', 'historically', 'ally', 'systemic'],
#  [],
#  ['ally'],
#  ['barrier', 'ally'],
#  [],
#  ['ally'],
#  [],
#  [],
#  ['ally'],
#  ['transgender',
#   'gender minority',
#   'gender',
#   'barrier',
#   'structural racism',
#   'barriers',
#   'racial disparities',
#   'discrimination',
#   'black people',
#   'minority',
#   'ally',
#   'racism',
#   'status',
#   'racial'],
#  [],
#  ['biases'],
#  ['women',
#   'black individuals',
#   'black individual',
#   'black men',
#   'black women'],
#  ['polarize', 'ally'],
#  ['ally'],
#  [],
#  ['barrier', 'exclusive', 'female', 'ally'],
#  ['ally'],
#  ['barrier', 'ally'],
#  ['ally', 'status'],
#  ['systemic'],
#  ['reparation', 'climate change', 'ally'],
#  ['systemic'],
#  ['ally'],
#  ['ally'],
#  ['ally'],
#  ['transgender',
#   'women',
#   'cisgender',
#   'gender',
#   'gender identity',
#   'gender affirming',
#   'ally'],
#  ['ally'],
#  ['advocate', 'ally'],
#  ['polarization', 'ally', 'systemic'],
#  [],
#  [],
#  ['barrier', 'ally'],
#  ['transgender',
#   'heterosexual',
#   'cisgender',
#   'gender',
#   'barrier',
#   'masculine',
#   'female',
#   'gender affirming',
#   'ally',
#   'marginalized',
#   'marginalize',
#   'underrepresented'],
#  ['ally'],
#  ['biased'],
#  ['ally', 'systemic'],
#  ['historically', 'ally'],
#  ['ally'],
#  ['ally'],
#  ['barrier', 'barriers'],
#  ['women', 'female', 'females', 'ally'],
#  ['barrier', 'ally'],
#  ['ally'],
#  ['ally'],
#  ['ally'],
#  ['lack of diversity',
#   'equity',
#   'diversifying',
#   'minority',
#   'diversify',
#   'underrepresented'],
#  ['ally'],
#  ['ally'],
#  ['ally'],
#  ['poc', 'ally'],
#  ['female', 'females', 'ally'],
#  [],
#  ['ally'],
#  ['ally'],
#  ['women'],
#  ['female', 'females'],
#  ['ally'],
#  ['ally'],
#  ['biased', 'gender', 'ally'],
#  ['ally'],
#  ['barrier', 'ally'],
#  ['ally', 'status'],
#  ['ally'],
#  ['ally'],
#  ['systemically', 'ally', 'systemic', 'systemical'],
#  ['ally'],
#  [],
#  ['ally'],
#  ['female', 'ally'],
#  ['poc'],
#  ['ally'],
#  ['ally'],
#  ['women', 'ally'],
#  ['ally'],
#  ['exclusive', 'ally'],
#  ['ally', 'systemic'],
#  ['biased', 'barrier', 'ally'],
#  ['ally'],
#  ['ally'],
#  ['ally'],
#  ['ally'],
#  ['barrier', 'female', 'barriers', 'females', 'ally'],
#  ...]

# %% [markdown]
# summaries that don't have any flagged words

# %%
idx = [i for i, x in enumerate(flagged) if isinstance(x, list) and not x]

# %%
no_flagged_terms = df.iloc[idx]
no_flagged_terms
# Out:
#       grant_id subgrant_id core_award_number  full_award_number activity_code  \
# 0     AA007459         NaN       T32AA007459    5T32AA007459-40           T32
# 18    AA029033         NaN       R21AA029033                NaN           R21
# 20    AA029044        04S1       R01AA029044  3R01AA029044-04S1           R01
# 25    AA029180         NaN       R00AA029180    5R00AA029180-05           R00
# 59    AA031213         NaN       R01AA031213    5R01AA031213-03           R01
# ...        ...         ...               ...                ...           ...
# 5246  NS128148         NaN       UG3NS128148  1UG3NS128148-01A1           UG3
# 5256  NS128947         NaN       R01NS128947    4R01NS128947-02           R01
# 5263  NS129589         NaN       F32NS129589    5F32NS129589-03           F32
# 5275  NS130475         NaN       R21NS130475                NaN           R21
# 5279  NS130838         NaN       R01NS130838    5R01NS130838-03           R01
#
#      institute_code  subproject_id current_status         detailed_status  \
# 0                AA            NaN       Restored    Unfrozen (confirmed)
# 18               AA            NaN       Restored    Unfrozen (confirmed)
# 20               AA            NaN      Disrupted              Terminated
# 25               AA            NaN       Restored    Unfrozen (confirmed)
# 59               AA            NaN       Restored  Reinstated (confirmed)
# ...             ...            ...            ...                     ...
# 5246             NS            NaN       Restored  Reinstated (confirmed)
# 5256             NS            NaN       Restored  Unfrozen (unconfirmed)
# 5263             NS            NaN       Restored  Reinstated (confirmed)
# 5275             NS            NaN       Restored    Unfrozen (confirmed)
# 5279             NS            NaN       Restored    Unfrozen (confirmed)
#
#                                                   title  ...  \
# 0     Alcohol Intervention Treatment Outcome Researc...  ...
# 18                                                  NaN  ...
# 20    Intersectional Approaches to Population-Level ...  ...
# 25    Corticolimbic Neuroimmune Determinants of Soci...  ...
# 59    The Impact of Stress on Alcohol-Related Sexual...  ...
# ...                                                 ...  ...
# 5246  Peripherally-restricted non-addictive cannabin...  ...
# 5256  High-Speed Imaging of Cortical and White Matte...  ...
# 5263  The Role of Mechanosensory Activity in the Tra...  ...
# 5275           Recognition of Shape by Vision and Touch  ...
# 5279  Development of Culturally Appropriate Spanish ...  ...
#
#                                       opportunity_title  \
# 0     Ruth L. Kirschstein National Research Service ...
# 18                                                  NaN
# 20    Accelerating the Pace of Drug Abuse Research U...
# 25    NIH Pathway to Independence Award (Parent K99/...
# 59    NIH Research Project Grant (Parent R01 Clinica...
# ...                                                 ...
# 5246  HEAL Initiative: Non-addictive Analgesic Thera...
# 5256  Selectively Target Technology Development to U...
# 5263  NINDS Ruth L. Kirschstein National Research Se...
# 5275                                                NaN
# 5279  NIH Research Project Grant (Parent R01 Clinica...
#
#                                         opportunity_url  \
# 0     https://grants.nih.gov/grants/guide/pa-files/P...
# 18                                                  NaN
# 20    https://grants.nih.gov/grants/guide/pa-files/P...
# 25    https://grants.nih.gov/grants/guide/pa-files/P...
# 59    https://grants.nih.gov/grants/guide/pa-files/P...
# ...                                                 ...
# 5246  https://grants.nih.gov/grants/guide/pa-files/R...
# 5256  https://grants.nih.gov/grants/guide/pa-files/P...
# 5263  https://grants.nih.gov/grants/guide/pa-files/P...
# 5275                                                NaN
# 5279  https://grants.nih.gov/grants/guide/pa-files/P...
#
#      current_total_obligated post_termination_deobligation award_value  \
# 0                 8903933.00                           NaN  8903933.00
# 18                 439344.12                           NaN   439344.12
# 20                       NaN                           NaN         NaN
# 25                1138465.00                           NaN  1138465.00
# 59                1671954.00                           NaN  1671954.00
# ...                      ...                           ...         ...
# 5246              3174343.00                           NaN  3174343.00
# 5256              3087726.00                           NaN  3087726.00
# 5263               221404.00                           NaN   221404.00
# 5275               438625.00                           NaN   438625.00
# 5279              1894593.00                           NaN  1894593.00
#
#      award_outlaid award_remaining  \
# 0       2021558.65      6882374.35
# 18       438066.63         1277.49
# 20             NaN             NaN
# 25       939517.30       198947.70
# 59       689957.48       981996.52
# ...            ...             ...
# 5246    2765310.19       409032.81
# 5256    2504171.37       583554.63
# 5263     189479.56        31924.44
# 5275     436212.61         2412.39
# 5279     869096.50      1025496.50
#
#                                            reporter_url  \
# 0     https://reporter.nih.gov/project-details/11098673
# 18                                                  NaN
# 20    https://reporter.nih.gov/project-details/11160901
# 25    https://reporter.nih.gov/project-details/11158870
# 59    https://reporter.nih.gov/project-details/11369221
# ...                                                 ...
# 5246  https://reporter.nih.gov/project-details/10726405
# 5256  https://reporter.nih.gov/project-details/10699914
# 5263  https://reporter.nih.gov/project-details/11017698
# 5275                                                NaN
# 5279  https://reporter.nih.gov/project-details/11243551
#
#                                         usaspending_url  \
# 0     https://www.usaspending.gov/award/ASST_NON_T32...
# 18    https://www.usaspending.gov/award/ASST_NON_R21...
# 20    https://www.usaspending.gov/award/ASST_NON_R01...
# 25    https://www.usaspending.gov/award/ASST_NON_R00...
# 59    https://www.usaspending.gov/award/ASST_NON_R01...
# ...                                                 ...
# 5246  https://www.usaspending.gov/award/ASST_NON_UG3...
# 5256  https://www.usaspending.gov/award/ASST_NON_R01...
# 5263  https://www.usaspending.gov/award/ASST_NON_F32...
# 5275  https://www.usaspending.gov/award/ASST_NON_R21...
# 5279  https://www.usaspending.gov/award/ASST_NON_R01...
#
#                                               taggs_url
# 0                                                   NaN
# 18                                                  NaN
# 20                                                  NaN
# 25                                                  NaN
# 59                                                  NaN
# ...                                                 ...
# 5246                                                NaN
# 5256                                                NaN
# 5263                                                NaN
# 5275  https://taggs.hhs.gov/Detail/AwardDetail?arg_A...
# 5279                                                NaN
#
# [606 rows x 63 columns]
